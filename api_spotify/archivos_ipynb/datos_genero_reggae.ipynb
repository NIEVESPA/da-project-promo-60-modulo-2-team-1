# %%
# pip install spotipy --upgrade

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import json

# %%
cliente = "18d8e23ee0a94acd9499bc06ae295e88"

# %%
secreto = "efcbe5326160470a9fee7d1f44edc254"

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(cliente, secreto)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q="genre:reggae, year:2000", type="track", limit=50, offset=0)

# %%
datos
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=genre%3Areggae%2C%20year%3A2000&type=track',
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=genre%3Areggae%2C%20year%3A2000&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#        'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#        'id': '3Isy6kedDrgPYoTS1dazA9',
#        'name': 'Sean Paul',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
# ...

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos["tracks"]
# Out:
# {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=genre%3Areggae%2C%20year%3A2000&type=track',
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=genre%3Areggae%2C%20year%3A2000&type=track',
#  'offset': 0,
#  'previous': None,
#  'total': 100,
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#       'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#       'id': '3Isy6kedDrgPYoTS1dazA9',
#       'name': 'Sean Paul',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
# ...

# %%
datos["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#      'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#      'id': '3Isy6kedDrgPYoTS1dazA9',
#      'name': 'Sean Paul',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
datos["tracks"]["items"][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#     'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#     'id': '3Isy6kedDrgPYoTS1dazA9',
#     'name': 'Sean Paul',
#     'type': 'artist',
#     'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
for i in datos["tracks"]["items"][0]["album"]:
 print(i)
# Out:
# album_type
# artists
# available_markets
# external_urls
# href
# id
# images
# is_playable
# name
# release_date
# release_date_precision
# total_tracks
# type
# uri

# %%
datos["tracks"]["items"][0]["album"]
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#    'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#    'id': '3Isy6kedDrgPYoTS1dazA9',
#    'name': 'Sean Paul',
#    'type': 'artist',
#    'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
datos["tracks"]["items"][0]["album"]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#   'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#   'id': '3Isy6kedDrgPYoTS1dazA9',
#   'name': 'Sean Paul',
#   'type': 'artist',
#   'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}]

# %%
datos["tracks"]["items"][0]["album"]["artists"][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'},
#  'href': 'https://api.spotify.com/v1/artists/3Isy6kedDrgPYoTS1dazA9',
#  'id': '3Isy6kedDrgPYoTS1dazA9',
#  'name': 'Sean Paul',
#  'type': 'artist',
#  'uri': 'spotify:artist:3Isy6kedDrgPYoTS1dazA9'}

# %%
datos["tracks"]["items"][0]["album"]["artists"][0]['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'}

# %%
datos["tracks"]["items"][0]["album"]["artists"][0]['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/artist/3Isy6kedDrgPYoTS1dazA9'

# %%
for track in datos['tracks']['items']:
    print(track['name'], track['popularity'])
tracks = datos['tracks']['items']
tracks_sorted = sorted(tracks, key=lambda t: t['popularity'], reverse=True)

for t in tracks_sorted:
    print(f"{t['name']} - Popularidad: {t['popularity']}")

    # Extraer indice de popularidad
# Out:
# Infiltrate 50
# Deport Them 51
# Luv Me, Luv Me 52
# Um Anjo do Céu 61
# Verde, Amarillo Y Rojo 54
# Caminando 51
# Here I Am (Come And Take Me) 55
# Señorita a Mi Me Gusta Su Style 53
# Jah Jah City 47
# Humble African 47
# Violencia Machista 33
# De Mi Mente 54
# ETTs 31
# If It Happens Again 48
# Kingston Town 50
# Mestizaje 48
# Ghost Town 67
# (I Can't Help) Falling In Love With You 50
# Tell Me Is It True 46
# The Way You Do The Things You Do 49
# Light My Fire 45
# Lucrecia 34
# Dulce Amor (Sólo Un Latido) 52
# La Mosca Cojonera 35
# Aire 57
# 99 Red Balloons 61
# I Got You Babe 51
# Lovers Rock 68
# Antonia 60
# Naval Xixon 37
# Why Am I A Rastaman? 49
# Rat In Mi Kitchen 40
# A la Mierda 51
# King 41
# Bring Me Your Cup - Edit 41
# Watchdogs 43
# Derecho De Admision 39
# I Got You Babe 43
# Higher Ground 44
# Red Red Wine 47
# Eres Un@ Mas 43
# Planeta Eskoria 45
# Kingston Town 47
# Tio Sam 43
# Bring Me Your Cup - Edit 57
# Sin Ti 35
# Vergüenza 46
# ...

# %%
for dato in datos['tracks']['items']:
    artista = dato['artists'][0]['name']
    nombre = dato['name']
    tipo = dato['type']
    ano = dato['album']['release_date']
    spotify_id = dato['id']
    print({'Artista': artista,'Género': 'rock','Tipo': tipo,'Nombre': nombre,'Año': ano,'ID': spotify_id})
    break
# Out:
# {'Artista': 'Sean Paul', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Infiltrate', 'Año': '2000', 'ID': '0ru8bc0XnKjUL2O1Fl1k7a'}

# %%
for dato in datos['tracks']['items']:
    artista = dato['artists'][0]['name']
    nombre = dato['name']
    tipo = dato['type']
    ano = dato['album']['release_date']
    spotify_id = dato['id']
    print({'Artista': artista,'Género': 'rock','Tipo': tipo,'Nombre': nombre,'Año': ano,'ID': spotify_id})
# Out:
# {'Artista': 'Sean Paul', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Infiltrate', 'Año': '2000', 'ID': '0ru8bc0XnKjUL2O1Fl1k7a'}
# {'Artista': 'Sean Paul', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Deport Them', 'Año': '2000', 'ID': '5KhypMVGqMI9mgsrrv2lxc'}
# {'Artista': 'Shaggy', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Luv Me, Luv Me', 'Año': '2000-08-08', 'ID': '7hV4x7PMKGC4qD3NWLt2UJ'}
# {'Artista': 'Maskavo', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Um Anjo do Céu', 'Año': '2000', 'ID': '2YgAAAq8h7nPIMVLVVSHtK'}
# {'Artista': 'Gondwana', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Verde, Amarillo Y Rojo', 'Año': '2000', 'ID': '4Q0y0SOAJ84PvR2Uu6tGXv'}
# {'Artista': 'Ganja', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Caminando', 'Año': '2000-10-27', 'ID': '5hirK8wva1Nh38fVwWdLlc'}
# {'Artista': 'UB40', 'Género': 'rock', 'Tipo': 'track', 'Nombre': 'Here I Am (Come And Take Me)', 'Año': '2000', 'ID': '6YR2MkzMhojHBmW1TbXtZO'}
# ...

# %%
listacanciones_reggae = []
for dato in datos['tracks']['items']:
    artista = dato['artists'][0]['name']
    nombre = dato['name']
    tipo = dato['type']
    ano = dato['album']['release_date']
    spotify_id = dato['id']
    datos_totales = (artista, nombre, tipo, ano, spotify_id)

    listacanciones_reggae.append({'Artista': artista,'Género': 'reggae','Tipo': tipo,'Nombre': nombre,'Año': ano,'ID': spotify_id}) #AÑADIR EL APPEND CON LA LISTA. HACER LA VARIABLE CON LA LISTA DE CANCIONES
print(listacanciones_reggae)
    #print({'Artista': artista,'Género': 'rock','Tipo': tipo,'Nombre': nombre,'Año': ano,'ID': spotify_id})
# Out:
# [{'Artista': 'Sean Paul', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Infiltrate', 'Año': '2000', 'ID': '0ru8bc0XnKjUL2O1Fl1k7a'}, {'Artista': 'Sean Paul', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Deport Them', 'Año': '2000', 'ID': '5KhypMVGqMI9mgsrrv2lxc'}, {'Artista': 'Shaggy', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Luv Me, Luv Me', 'Año': '2000-08-08', 'ID': '7hV4x7PMKGC4qD3NWLt2UJ'}, {'Artista': 'Maskavo', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Um Anjo do Céu', 'Año': '2000', 'ID': '2YgAAAq8h7nPIMVLVVSHtK'}, {'Artista': 'Gondwana', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Verde, Amarillo Y Rojo', 'Año': '2000', 'ID': '4Q0y0SOAJ84PvR2Uu6tGXv'}, {'Artista': 'Ganja', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Caminando', 'Año': '2000-10-27', 'ID': '5hirK8wva1Nh38fVwWdLlc'}, {'Artista': 'UB40', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Here I Am (Come And Take Me)', 'Año': '2000', 'ID': '6YR2MkzMhojHBmW1TbXtZO'}, {'Artista': 'Los Rabanes
# ...

# %%
for diccionario in listacanciones_reggae:
    print (diccionario)
# Out:
# {'Artista': 'Sean Paul', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Infiltrate', 'Año': '2000', 'ID': '0ru8bc0XnKjUL2O1Fl1k7a'}
# {'Artista': 'Sean Paul', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Deport Them', 'Año': '2000', 'ID': '5KhypMVGqMI9mgsrrv2lxc'}
# {'Artista': 'Shaggy', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Luv Me, Luv Me', 'Año': '2000-08-08', 'ID': '7hV4x7PMKGC4qD3NWLt2UJ'}
# {'Artista': 'Maskavo', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Um Anjo do Céu', 'Año': '2000', 'ID': '2YgAAAq8h7nPIMVLVVSHtK'}
# {'Artista': 'Gondwana', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Verde, Amarillo Y Rojo', 'Año': '2000', 'ID': '4Q0y0SOAJ84PvR2Uu6tGXv'}
# {'Artista': 'Ganja', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Caminando', 'Año': '2000-10-27', 'ID': '5hirK8wva1Nh38fVwWdLlc'}
# {'Artista': 'UB40', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Here I Am (Come And Take Me)', 'Año': '2000', 'ID': '6YR2MkzMhojHBmW1TbXtZO'}
# ...

# %%
#CREACIÓN DEL DATAFRAME
df_reggae = pd.DataFrame(listacanciones_reggae)

df_reggae
# Out:
#          Artista  Género   Tipo                                   Nombre  \
# 0      Sean Paul  reggae  track                               Infiltrate
# 1      Sean Paul  reggae  track                              Deport Them
# 2         Shaggy  reggae  track                           Luv Me, Luv Me
# 3        Maskavo  reggae  track                           Um Anjo do Céu
# 4       Gondwana  reggae  track                   Verde, Amarillo Y Rojo
# 5          Ganja  reggae  track                                Caminando
# 6           UB40  reggae  track             Here I Am (Come And Take Me)
# 7    Los Rabanes  reggae  track          Señorita a Mi Me Gusta Su Style
# 8       Capleton  reggae  track                             Jah Jah City
# 9        Culture  reggae  track                           Humble African
# 10         Ska-P  reggae  track                       Violencia Machista
# 11    Los Cafres  reggae  track                              De Mi Mente
# ...

# %%
for año in range(2000, 2005):
    for cancion in range (0,150,50):
        q=f"genre:raggae, year:{año}"
    print(q)
# Out:
# genre:raggae, year:2000
# genre:raggae, year:2001
# genre:raggae, year:2002
# genre:raggae, year:2003
# genre:raggae, year:2004

# %%
listacanciones_reggae = []
for anio in range (2000, 2005):
    for offset in range (0,150,50):
     datos = sp.search(q=f"genre:reggae, year:{anio}", type="track", limit=50, offset=offset)

     for dato in datos['tracks']['items']:
         artista = dato['artists'][0]['name']
         genero = 'latin pop'
         nombre = dato['name']
         tipo = dato['type']
         anio = dato['album']['release_date'][:4]
         spotify_id = dato['id']
       
         informacion_artista = {'Artista': artista, 'Género': 'reggae', 'Tipo': tipo, 'Nombre': nombre, 'Año': ano,'ID': spotify_id} 

         listacanciones_reggae.append(informacion_artista)

print(listacanciones_reggae)
# Out:
# [{'Artista': 'Sean Paul', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Infiltrate', 'Año': '2000-08-08', 'ID': '0ru8bc0XnKjUL2O1Fl1k7a'}, {'Artista': 'Sean Paul', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Deport Them', 'Año': '2000-08-08', 'ID': '5KhypMVGqMI9mgsrrv2lxc'}, {'Artista': 'Shaggy', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Luv Me, Luv Me', 'Año': '2000-08-08', 'ID': '7hV4x7PMKGC4qD3NWLt2UJ'}, {'Artista': 'Maskavo', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Um Anjo do Céu', 'Año': '2000-08-08', 'ID': '2YgAAAq8h7nPIMVLVVSHtK'}, {'Artista': 'Gondwana', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Verde, Amarillo Y Rojo', 'Año': '2000-08-08', 'ID': '4Q0y0SOAJ84PvR2Uu6tGXv'}, {'Artista': 'Ganja', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Caminando', 'Año': '2000-08-08', 'ID': '5hirK8wva1Nh38fVwWdLlc'}, {'Artista': 'UB40', 'Género': 'reggae', 'Tipo': 'track', 'Nombre': 'Here I Am (Come And Take Me)', 'Año': '2000-08-08', 'ID': '6YR2MkzMhojHBmW1TbXt
# ...

# %%
df_reggae = pd.DataFrame(listacanciones_reggae)

df_reggae
# Out:
#                   Artista  Género   Tipo  \
# 0               Sean Paul  reggae  track
# 1               Sean Paul  reggae  track
# 2                  Shaggy  reggae  track
# 3                 Maskavo  reggae  track
# 4                Gondwana  reggae  track
# ..                    ...     ...    ...
# 745  Thievery Corporation  reggae  track
# 746           Groundation  reggae  track
# 747          Dancing Mood  reggae  track
# 748             Joe Dukie  reggae  track
# 749             Holy Piby  reggae  track
#
#                                                 Nombre         Año  \
# 0                                           Infiltrate  2000-08-08
# 1                                          Deport Them  2000-08-08
# 2                                       Luv Me, Luv Me  2000-08-08
# 3                                       Um Anjo do Céu  2000-08-08
# 4                               Verde, Amarillo Y Rojo  2000-08-08
# ...

# %%
df_reggae.to_csv("df_reggae.csv")
