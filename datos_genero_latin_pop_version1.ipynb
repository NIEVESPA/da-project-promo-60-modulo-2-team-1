# %% [markdown]
# Tareas: Extraer canciones y álbumes lanzados entre 2000 y 2005.
#
# Extraer la siguiente información:
#
# [ ] Artista.
#
# [ ] Género musical.
#
# [ ] Tipo (canción o álbum).
#
# [ ] Nombre.
#
# [ ] Año de lanzamiento.
#
# [ ] ID.

# %%
import spotipy #importo, una vez quiero usarla en c/nb

from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
secreto = ###
cliente = ###

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(cliente, secreto)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
query = sp.search(q="genre:latin pop, year:2005", type="track", limit=50, offset=0) #usamos offset=0 para obtener los primeros 50

# %%
lista_artistas = query['tracks']['items'][0]['album']['artists'] #analizamos los len que contiene el diccionario y los puntos de acceso a la info
lista_artistas
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0h1zs4CTlU9D2QtgPxptUD'},
#   'href': 'https://api.spotify.com/v1/artists/0h1zs4CTlU9D2QtgPxptUD',
#   'id': '0h1zs4CTlU9D2QtgPxptUD',
#   'name': 'Ricardo Arjona',
#   'type': 'artist',
#   'uri': 'spotify:artist:0h1zs4CTlU9D2QtgPxptUD'}]

# %%
for artista in lista_artistas:
    print(artista['name'])
# Out:
# Ricardo Arjona

# %%
for track in query['tracks']['items']: ###para acceder a la popularidad del tema
    print(track['name'], track['popularity'])
# Out:
# De Vez en Mes 49
# テ・キエロ・ディヒステ 53
# Qué Hay Detrás 57
# Seduccion 55
# 遠く離れても 51
# Sway 52
# En Tus Pupilas 48
# Te Doy Mi Amor 51
# Popurri 39
# No te apartes de mí 54
# La Pared 52
# Mojado 55
# Te necesito 54
# Quiero 42
# No Me Canso - Inedito 27
# Suelta Mi Mano 66
# A Ti 51
# Obtener un Si 45
# Ai mi morena - Chocolate Restyle 43
# キエンセラ 52
# No Te Preocupes por Mi 47
# Como Me Mira 55
# Dia Especial (feat. Gustavo Cerati) 50
# Te Echo de Menos 49
# Pingüinos en la Cama 70
# ¿Qué Hago Yo? 65
# Tras De Mí 65
# Aún Hay Algo 61
# Acompáñame a Estar Solo 69
# Qué Vida la Mía 66
# Que Me Alcance la Vida 65
# Popurri Kchaka Piru (Bailando Guararé / Anhelos / La Rosita / Mi Negra) 22
# Pídeme 53
# No (feat. Gustavo Cerati) 65
# A Ti 66
# Nada Fue Un Error - Live In Spain / 2005 63
# La Cabaña 59
# No Te Pido Flores 58
# Las de la Intuición 76
# Este Corazón 66
# La Tortura (feat. Alejandro Sanz) 80
# Nuestro Amor 59
# Hace Tiempo 60
# ベサメ・ムーチョ 64
# Te Mando Flores 72
# Día de Enero 77
# Popurrí Juan Gabriel / Ya Lo Sé Que Tú Te Vas / La Diferencia / Te Sigo Amando - En Vivo 47
# Nada Fue Un Error - Live In Spain / 2005 48
# Yo Quisiera 76
# Noviembre Sin Ti 74

# %%
for dato in query['tracks']['items']: #iteramos en los elementos que componen items
    artista = dato['artists'][0]['name']
    genero = 'latin pop'
    nombre = dato['name']
    tipo = dato['type']
    ano = dato['album']['release_date']
    spotify_id = dato['id']
    print({'Artista': artista,'Género': 'latin pop','Tipo': tipo,'Nombre': nombre,'Año': ano,'ID': spotify_id})
    break ##detiene la lista despues del primer elemento, por lo que solo guardarías uno
# Out:
# {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'De Vez en Mes', 'Año': '2005-12-06', 'ID': '7dkw2lSgDwyhHZYoVgMclt'}

# %%
lista_latin_pop = [] #lista vacia antes del bucle

for dato in query['tracks']['items']: #recorremos los elementos
    artista = dato['artists'][0]['name']
    genero = 'latin pop'
    nombre = dato['name']
    tipo = dato['type']
    ano = dato['album']['release_date']
    spotify_id = dato['id']

    informacion_artista= {'Artista': artista, 'Género': 'latin pop', 'Tipo': tipo, 'Nombre': nombre, 'Año': ano,'ID': spotify_id} #creamos un diccionario con la info que queremos recopila de cada truck. nota: genero str

    lista_latin_pop.append(informacion_artista)
    #elimino brake para que me salgan todos los elementos de query

print(lista_latin_pop)
# Out:
# [{'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'De Vez en Mes', 'Año': '2005-12-06', 'ID': '7dkw2lSgDwyhHZYoVgMclt'}, {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'テ・キエロ・ディヒステ', 'Año': '2005-06-29', 'ID': '1xjGMWxSfbo7Eyjeb3mzNs'}, {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Qué Hay Detrás', 'Año': '2005-01-01', 'ID': '5Ya2WSoqPdAkmohiRZgZGl'}, {'Artista': 'Thalia', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Seduccion', 'Año': '2005-01-01', 'ID': '1YMr1YzK04rKlN8vt03nPP'}, {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': '遠く離れても', 'Año': '2005-08-19', 'ID': '35i2XFc60eKVIu9SlRIRCH'}, {'Artista': 'The Pussycat Dolls', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Sway', 'Año': '2005-01-01', 'ID': '01xXQbDsWMJVBKOoKWXE8h'}, {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'En Tus Pupilas', 'Año': '2005-06-03', 'ID': '7046NJqL0E7v5THigdTOyE'}, {'Artista': 'Bacanos', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te Doy Mi Amor', 'Año': '2005-05-05', 'ID': '5cgwBlY1oNdnuNsy4PaXAz'}, {'Artista': 'Aniceto Molina', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Popurri', 'Año': '2005-03-01', 'ID': '5ndbUsAt6oyeBhZZ4U1NH4'}, {'Artista': 'Yahir', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No te apartes de mí', 'Año': '2005-09-20', 'ID': '7EC5RB8EDJOWXcYlk9HLwr'}, {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'La Pared', 'Año': '2005-06-03', 'ID': '35idKzsNHvyALKIZ9JHw47'}, {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Mojado', 'Año': '2005-12-06', 'ID': '5Qchpm6oOiHytt5dIk69Ij'}, {'Artista': 'Luis Miguel', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te necesito', 'Año': '2005-12-02', 'ID': '6fM4uVlC2brb5Di9O1vvry'}, {'Artista': 'Calle Ciega', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Quiero', 'Año': '2005-01-01', 'ID': '3b11hXQgd8rXcROT2qRcJp'}, {'Artista': 'Ana Torroja', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No Me Canso - Inedito', 'Año': '2005', 'ID': '2apIAlbkN6IgvucbM5PCdo'}, {'Artista': 'Sin Bandera', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Suelta Mi Mano', 'Año': '2005-11-18', 'ID': '50xvGsnNmO3k5EtaUBXRRr'}, {'Artista': 'Sin Bandera', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'A Ti', 'Año': '2005-11-18', 'ID': '1EtN1I3hbkuIl6zka9XhJ3'}, {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Obtener un Si', 'Año': '2005-06-03', 'ID': '0OUVKbGfxGA6rdvqwxwyWV'}, {'Artista': "Mo' Horizons", 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Ai mi morena - Chocolate Restyle', 'Año': '2005-08-22', 'ID': '195rt3pQCPzYDmobHp9uL5'}, {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'キエンセラ', 'Año': '2005-08-19', 'ID': '6pTh0DeJkVDvv1ytHlwDiA'}, {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No Te Preocupes por Mi', 'Año': '2005', 'ID': '0NN9TRTvceycUm8wq30yk8'}, {'Artista': 'Fonseca', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Como Me Mira', 'Año': '2005-05-01', 'ID': '1OwZtvGw2BNYjmLHoGfrY4'}, {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Dia Especial (feat. Gustavo Cerati)', 'Año': '2005-06-03', 'ID': '2EZ4NSQtoKdiWK8JDMY7NT'}, {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te Echo de Menos', 'Año': '2005', 'ID': '5OkWLb3GzvjYUrhSpQFbvn'}, {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Pingüinos en la Cama', 'Año': '2005-12-06', 'ID': '73X4fA2RX6ycvEsFvDIUs4'}, {'Artista': 'Ha*Ash', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': '¿Qué Hago Yo?', 'Año': '2005', 'ID': '5fISatRSvu52jsmsnKwNfY'}, {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Tras De Mí', 'Año': '2005-01-01', 'ID': '1AO5MeGsWdPLejY47pnYYy'}, {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': ' ...

# %%
# IMPRESIÓN POR FILAS SEPARADAS

for diccionario in lista_latin_pop:
    print(diccionario)
# Out:
# {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'De Vez en Mes', 'Año': '2005-12-06', 'ID': '7dkw2lSgDwyhHZYoVgMclt'}
# {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'テ・キエロ・ディヒステ', 'Año': '2005-06-29', 'ID': '1xjGMWxSfbo7Eyjeb3mzNs'}
# {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Qué Hay Detrás', 'Año': '2005-01-01', 'ID': '5Ya2WSoqPdAkmohiRZgZGl'}
# {'Artista': 'Thalia', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Seduccion', 'Año': '2005-01-01', 'ID': '1YMr1YzK04rKlN8vt03nPP'}
# {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': '遠く離れても', 'Año': '2005-08-19', 'ID': '35i2XFc60eKVIu9SlRIRCH'}
# {'Artista': 'The Pussycat Dolls', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Sway', 'Año': '2005-01-01', 'ID': '01xXQbDsWMJVBKOoKWXE8h'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'En Tus Pupilas', 'Año': '2005-06-03', 'ID': '7046NJqL0E7v5THigdTOyE'}
# {'Artista': 'Bacanos', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te Doy Mi Amor', 'Año': '2005-05-05', 'ID': '5cgwBlY1oNdnuNsy4PaXAz'}
# {'Artista': 'Aniceto Molina', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Popurri', 'Año': '2005-03-01', 'ID': '5ndbUsAt6oyeBhZZ4U1NH4'}
# {'Artista': 'Yahir', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No te apartes de mí', 'Año': '2005-09-20', 'ID': '7EC5RB8EDJOWXcYlk9HLwr'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'La Pared', 'Año': '2005-06-03', 'ID': '35idKzsNHvyALKIZ9JHw47'}
# {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Mojado', 'Año': '2005-12-06', 'ID': '5Qchpm6oOiHytt5dIk69Ij'}
# {'Artista': 'Luis Miguel', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te necesito', 'Año': '2005-12-02', 'ID': '6fM4uVlC2brb5Di9O1vvry'}
# {'Artista': 'Calle Ciega', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Quiero', 'Año': '2005-01-01', 'ID': '3b11hXQgd8rXcROT2qRcJp'}
# {'Artista': 'Ana Torroja', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No Me Canso - Inedito', 'Año': '2005', 'ID': '2apIAlbkN6IgvucbM5PCdo'}
# {'Artista': 'Sin Bandera', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Suelta Mi Mano', 'Año': '2005-11-18', 'ID': '50xvGsnNmO3k5EtaUBXRRr'}
# {'Artista': 'Sin Bandera', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'A Ti', 'Año': '2005-11-18', 'ID': '1EtN1I3hbkuIl6zka9XhJ3'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Obtener un Si', 'Año': '2005-06-03', 'ID': '0OUVKbGfxGA6rdvqwxwyWV'}
# {'Artista': "Mo' Horizons", 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Ai mi morena - Chocolate Restyle', 'Año': '2005-08-22', 'ID': '195rt3pQCPzYDmobHp9uL5'}
# {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'キエンセラ', 'Año': '2005-08-19', 'ID': '6pTh0DeJkVDvv1ytHlwDiA'}
# {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No Te Preocupes por Mi', 'Año': '2005', 'ID': '0NN9TRTvceycUm8wq30yk8'}
# {'Artista': 'Fonseca', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Como Me Mira', 'Año': '2005-05-01', 'ID': '1OwZtvGw2BNYjmLHoGfrY4'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Dia Especial (feat. Gustavo Cerati)', 'Año': '2005-06-03', 'ID': '2EZ4NSQtoKdiWK8JDMY7NT'}
# {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te Echo de Menos', 'Año': '2005', 'ID': '5OkWLb3GzvjYUrhSpQFbvn'}
# {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Pingüinos en la Cama', 'Año': '2005-12-06', 'ID': '73X4fA2RX6ycvEsFvDIUs4'}
# {'Artista': 'Ha*Ash', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': '¿Qué Hago Yo?', 'Año': '2005', 'ID': '5fISatRSvu52jsmsnKwNfY'}
# {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Tras De Mí', 'Año': '2005-01-01', 'ID': '1AO5MeGsWdPLejY47pnYYy'}
# {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Aún Hay Algo', 'Año': '2005-01-01', 'ID': '6fqpsCQ7jF7OgQolXgYovX'}
# {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Acompáñame a Estar Solo', 'Año': '2005-12-06', 'ID': '5rwl9TKyjbAVSCUOBZz77Y'}
# {'Artista': 'Reik', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Qué Vida la Mía', 'Año': '2005-03-02', 'ID': '0M6KY0x5u65ybXHZ3IAega'}
# {'Artista': 'Sin Bandera', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Que Me Alcance la Vida', 'Año': '2005-11-18', 'ID': '0doPUFYZPjLAFNfqoZy7Jw'}
# {'Artista': 'Frecuencia Trio', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Popurri Kchaka Piru (Bailando Guararé / Anhelos / La Rosita / Mi Negra)', 'Año': '2005', 'ID': '64HTYIDH9Y6vW53FV6AoLg'}
# {'Artista': 'Guaco', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Pídeme', 'Año': '2005-07-01', 'ID': '3dqgHG4Rksh3B04Dt3cVHu'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No (feat. Gustavo Cerati)', 'Año': '2005-06-03', 'ID': '7CZkVQ8LsfDsu8STKAQfWY'}
# {'Artista': 'Ricardo Arjona', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'A Ti', 'Año': '2005-12-06', 'ID': '5CcBo88PRHzJeQdiE5mBNi'}
# {'Artista': 'Coti', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Nada Fue Un Error - Live In Spain / 2005', 'Año': '2005-01-01', 'ID': '7GO6pBFbieZ30NjGIp2LP5'}
# {'Artista': "La K'onga", 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'La Cabaña', 'Año': '2005-11-04', 'ID': '5TpGT4K34mBP6JcJfIgRqF'}
# {'Artista': 'Fanny Lu', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'No Te Pido Flores', 'Año': '2005-01-01', 'ID': '2ctc9nwRgXeeIFaFWTRrRl'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Las de la Intuición', 'Año': '2005-06-03', 'ID': '7DnMd3BxVOedyOyR7K3F8L'}
# {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Este Corazón', 'Año': '2005-01-01', 'ID': '0bMVCO35RJiUhAfvFsLjIF'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'La Tortura (feat. Alejandro Sanz)', 'Año': '2005-06-03', 'ID': '53AafWSzYsiJKnAtJTUB5f'}
# {'Artista': 'RBD', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Nuestro Amor', 'Año': '2005-01-01', 'ID': '7F7qwp7VZRVwZsNoddRRgX'}
# {'Artista': 'Fonseca', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Hace Tiempo', 'Año': '2005-05-01', 'ID': '7G0Z77RdBTdf4bt45AL6yS'}
# {'Artista': 'Lisa Ono', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'ベサメ・ムーチョ', 'Año': '2005-08-19', 'ID': '26nkboSGZauLZQJo2Ni1vA'}
# {'Artista': 'Fonseca', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Te Mando Flores', 'Año': '2005-05-01', 'ID': '2in1gSZtv2lRbcZUmN9aAl'}
# {'Artista': 'Shakira', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Día de Enero', 'Año': '2005-06-03', 'ID': '2u24GtkbktY3HB3souJdNY'}
# {'Artista': 'Alejandro Fernández', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Popurrí Juan Gabriel / Ya Lo Sé Que Tú Te Vas / La Diferencia / Te Sigo Amando - En Vivo', 'Año': '2005-10-20', 'ID': '2APE7KXnCG2IFP66BVdZis'}
# {'Artista': 'Coti', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Nada Fue Un Error - Live In Spain / 2005', 'Año': '2005-01-01', 'ID': '15RAXEkBCh62ZB6xddv0wO'}
# {'Artista': 'Reik', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Yo Quisiera', 'Año': '2005-03-02', 'ID': '2GSr8anleCXKLNjjjijoMZ'}
# {'Artista': 'Reik', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Noviembre Sin Ti', 'Año': '2005-03-02', 'ID': '2vCHDrXVN0k1GPTjSIZ69E'}

# %%
# CREACIÓN DEL DATAFRAME
df_latin_pop = pd.DataFrame(lista_latin_pop)

df_latin_pop #en print o cvs añadir (index=False) para eliminar ese primer indice
# Out:
#                 Artista     Género   Tipo  \
# 0        Ricardo Arjona  latin pop  track
# 1              Lisa Ono  latin pop  track
# 2                   RBD  latin pop  track
# 3                Thalia  latin pop  track
# 4              Lisa Ono  latin pop  track
# 5    The Pussycat Dolls  latin pop  track
# 6               Shakira  latin pop  track
# 7               Bacanos  latin pop  track
# 8        Aniceto Molina  latin pop  track
# 9                 Yahir  latin pop  track
# 10              Shakira  latin pop  track
# 11       Ricardo Arjona  latin pop  track
# 12          Luis Miguel  latin pop  track
# 13          Calle Ciega  latin pop  track
# 14          Ana Torroja  latin pop  track
# 15          Sin Bandera  latin pop  track
# 16          Sin Bandera  latin pop  track
# 17              Shakira  latin pop  track
# 18         Mo' Horizons  latin pop  track
# 19             Lisa Ono  latin pop  track
# 20             Chayanne  latin pop  track
# 21              Fonseca  latin pop  track
# 22              Shakira  latin pop  track
# 23             Chayanne  latin pop  track
# 24       Ricardo Arjona  latin pop  track
# 25               Ha*Ash  latin pop  track
# 26                  RBD  latin pop  track
# 27                  RBD  latin pop  track
# 28       Ricardo Arjona  latin pop  track
# 29                 Reik  latin pop  track
# 30          Sin Bandera  latin pop  track
# 31      Frecuencia Trio  latin pop  track
# 32                Guaco  latin pop  track
# 33              Shakira  latin pop  track
# 34       Ricardo Arjona  latin pop  track
# 35                 Coti  latin pop  track
# 36            La K'onga  latin pop  track
# 37             Fanny Lu  latin pop  track
# 38              Shakira  latin pop  track
# 39                  RBD  latin pop  track
# 40              Shakira  latin pop  track
# 41                  RBD  latin pop  track
# 42              Fonseca  latin pop  track
# 43             Lisa Ono  latin pop  track
# 44              Fonseca  latin pop  track
# 45              Shakira  latin pop  track
# 46  Alejandro Fernández  latin pop  track
# 47                 Coti  latin pop  track
# 48                 Reik  latin pop  track
# 49                 Reik  latin pop  track
#
#                                                Nombre         Año  \
# 0                                       De Vez en Mes  2005-12-06
# 1                                         テ・キエロ・ディヒステ  2005-06-29
# 2                                      Qué Hay Detrás  2005-01-01
# 3                                           Seduccion  2005-01-01
# 4                                              遠く離れても  2005-08-19
# 5                                                Sway  2005-01-01
# 6                                      En Tus Pupilas  2005-06-03
# 7                                      Te Doy Mi Amor  2005-05-05
# 8                                             Popurri  2005-03-01
# 9                                 No te apartes de mí  2005-09-20
# 10                                           La Pared  2005-06-03
# 11                                             Mojado  2005-12-06
# 12                                        Te necesito  2005-12-02
# 13                                             Quiero  2005-01-01
# 14                              No Me Canso - Inedito        2005
# 15                                     Suelta Mi Mano  2005-11-18
# 16                                               A Ti  2005-11-18
# 17                                      Obtener un Si  2005-06-03
# 18                   Ai mi morena - Chocolate Restyle  2005-08-22
# 19                                              キエンセラ  2005-08-19
# 20                             No Te Preocupes por Mi        2005
# 21                                       Como Me Mira  2005-05-01
# 22                Dia Especial (feat. Gustavo Cerati)  2005-06-03
# 23                                   Te Echo de Menos        2005
# 24                               Pingüinos en la Cama  2005-12-06
# 25                                      ¿Qué Hago Yo?        2005
# 26                                         Tras De Mí  2005-01-01
# 27                                       Aún Hay Algo  2005-01-01
# 28                            Acompáñame a Estar Solo  2005-12-06
# 29                                    Qué Vida la Mía  2005-03-02
# 30                             Que Me Alcance la Vida  2005-11-18
# 31  Popurri Kchaka Piru (Bailando Guararé / Anhelo...        2005
# 32                                             Pídeme  2005-07-01
# 33                          No (feat. Gustavo Cerati)  2005-06-03
# 34                                               A Ti  2005-12-06
# 35           Nada Fue Un Error - Live In Spain / 2005  2005-01-01
# 36                                          La Cabaña  2005-11-04
# 37                                  No Te Pido Flores  2005-01-01
# 38                                Las de la Intuición  2005-06-03
# 39                                       Este Corazón  2005-01-01
# 40                  La Tortura (feat. Alejandro Sanz)  2005-06-03
# 41                                       Nuestro Amor  2005-01-01
# 42                                        Hace Tiempo  2005-05-01
# 43                                           ベサメ・ムーチョ  2005-08-19
# 44                                    Te Mando Flores  2005-05-01
# 45                                       Día de Enero  2005-06-03
# 46  Popurrí Juan Gabriel / Ya Lo Sé Que Tú Te Vas ...  2005-10-20
# 47           Nada Fue Un Error - Live In Spain / 2005  2005-01-01
# 48                                        Yo Quisiera  2005-03-02
# 49                                   Noviembre Sin Ti  2005-03-02
#
#                         ID
# 0   7dkw2lSgDwyhHZYoVgMclt
# 1   1xjGMWxSfbo7Eyjeb3mzNs
# 2   5Ya2WSoqPdAkmohiRZgZGl
# 3   1YMr1YzK04rKlN8vt03nPP
# 4   35i2XFc60eKVIu9SlRIRCH
# 5   01xXQbDsWMJVBKOoKWXE8h
# 6   7046NJqL0E7v5THigdTOyE
# 7   5cgwBlY1oNdnuNsy4PaXAz
# 8   5ndbUsAt6oyeBhZZ4U1NH4
# 9   7EC5RB8EDJOWXcYlk9HLwr
# 10  35idKzsNHvyALKIZ9JHw47
# 11  5Qchpm6oOiHytt5dIk69Ij
# 12  6fM4uVlC2brb5Di9O1vvry
# 13  3b11hXQgd8rXcROT2qRcJp
# 14  2apIAlbkN6IgvucbM5PCdo
# 15  50xvGsnNmO3k5EtaUBXRRr
# 16  1EtN1I3hbkuIl6zka9XhJ3
# 17  0OUVKbGfxGA6rdvqwxwyWV
# 18  195rt3pQCPzYDmobHp9uL5
# 19  6pTh0DeJkVDvv1ytHlwDiA
# 20  0NN9TRTvceycUm8wq30yk8
# 21  1OwZtvGw2BNYjmLHoGfrY4
# 22  2EZ4NSQtoKdiWK8JDMY7NT
# 23  5OkWLb3GzvjYUrhSpQFbvn
# 24  73X4fA2RX6ycvEsFvDIUs4
# 25  5fISatRSvu52jsmsnKwNfY
# 26  1AO5MeGsWdPLejY47pnYYy
# 27  6fqpsCQ7jF7OgQolXgYovX
# 28  5rwl9TKyjbAVSCUOBZz77Y
# 29  0M6KY0x5u65ybXHZ3IAega
# 30  0doPUFYZPjLAFNfqoZy7Jw
# 31  64HTYIDH9Y6vW53FV6AoLg
# 32  3dqgHG4Rksh3B04Dt3cVHu
# 33  7CZkVQ8LsfDsu8STKAQfWY
# 34  5CcBo88PRHzJeQdiE5mBNi
# 35  7GO6pBFbieZ30NjGIp2LP5
# 36  5TpGT4K34mBP6JcJfIgRqF
# 37  2ctc9nwRgXeeIFaFWTRrRl
# 38  7DnMd3BxVOedyOyR7K3F8L
# 39  0bMVCO35RJiUhAfvFsLjIF
# 40  53AafWSzYsiJKnAtJTUB5f
# 41  7F7qwp7VZRVwZsNoddRRgX
# 42  7G0Z77RdBTdf4bt45AL6yS
# 43  26nkboSGZauLZQJo2Ni1vA
# 44  2in1gSZtv2lRbcZUmN9aAl
# 45  2u24GtkbktY3HB3souJdNY
# 46  2APE7KXnCG2IFP66BVdZis
# 47  15RAXEkBCh62ZB6xddv0wO
# 48  2GSr8anleCXKLNjjjijoMZ
# 49  2vCHDrXVN0k1GPTjSIZ69E

# %%
for año in range(2000, 2005):
    for cancion in range (0,150,50):
        q=f"genre:latin_pop, year:{año}"
    print(q)
# Out:
# genre:latin_pop, year:2000
# genre:latin_pop, year:2001
# genre:latin_pop, year:2002
# genre:latin_pop, year:2003
# genre:latin_pop, year:2004

# %%
lista_latin_pop = [] #lista vacia antes del bucle

for ano in range(2000, 2005):
    for offset in range (0,150,50):
        
        query = sp.search(q=f"genre:latin pop, year:{ano}", type="track", limit=50, offset=offset)

        for dato in query['tracks']['items']:
            artista = dato['artists'][0]['name']
            genero = 'latin pop'
            nombre = dato['name']
            tipo = dato['type']
            ano = dato['album']['release_date'][:4]
            spotify_id = dato['id']

            informacion_artista= {'Artista': artista, 'Género': 'latin pop', 'Tipo': tipo, 'Nombre': nombre, 'Año': ano,'ID': spotify_id} #creamos un diccionario con la info que queremos recopila de cada truck. nota: genero str

            lista_latin_pop.append(informacion_artista)

print(lista_latin_pop)
# Out:
# [{'Artista': 'La Oreja de Van Gogh', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Pop', 'Año': '2000', 'ID': '4FXSEdmbbeGmPIQltH27C8'}, {'Artista': 'Thalia', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Entre El Mar Y Una Estrella', 'Año': '2000', 'ID': '2KNtKG2X0jpOIgVunVbAkQ'}, {'Artista': 'Ricky Martin', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'She Bangs - Spanish Version', 'Año': '2000', 'ID': '4ti5pZ0zs1PDf1eQswskFB'}, {'Artista': 'Thalia', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Regresa A Mi', 'Año': '2000', 'ID': '36GbwUTkCSQ18aysIFYEPF'}, {'Artista': 'Paulina Rubio', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Tal Vez Quizas', 'Año': '2000', 'ID': '4Ft4AbNwk1acKagaBOmvHb'}, {'Artista': 'Rodrigo', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Soy Cordobes', 'Año': '2000', 'ID': '5wG4J1UECH0c42YhMhSkcS'}, {'Artista': 'Los Tucanes De Tijuana', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Mis Tres Viejas', 'Año': '2000', 'ID': '1yxJIFPhP2EqnQ6oWJKbmP'}, {'Artista': 'Alejandro Sanz', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Para que me quieras', 'Año': '2000', 'ID': '3QYWYwpcCdf5f5DQW52oaz'}, {'Artista': 'Rodrigo', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Como Le Digo', 'Año': '2000', 'ID': '4nH1lpWkgzQPpTYPPjWKaI'}, {'Artista': 'Rodrigo', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Fuego y Pasion', 'Año': '2000', 'ID': '0SBHkYiZh8ih1RHoOcDtHl'}, {'Artista': 'Monica Naranjo', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Enamorada', 'Año': '2000', 'ID': '3W5v2CXAqEr6aa70MMNVYK'}, {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Boom Boom', 'Año': '2000', 'ID': '4zkOTmiamebLJ39Sqbp7sb'}, {'Artista': 'Alejandro Sanz', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Cuando nadie me ve - Maqueta', 'Año': '2000', 'ID': '7IxcEDXDSefpahEg6zmDs5'}, {'Artista': 'Celia Cruz', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': "Celia's Oye Como Va (Oye Como Va)", 'Año': '2000', 'ID': '7fhCXXF7V5jsU06bOgVBqJ'}, {'Artista': 'Ana Torroja', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Duende', 'Año': '2000', 'ID': '3WX2KhnJq3QdRTfPgHWgZU'}, {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Candela', 'Año': '2000', 'ID': '6aZVaIudGaHm88ydUe9k4i'}, {'Artista': 'Laura Pausini', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Un error de los grandes', 'Año': '2000', 'ID': '0cZRvN0JNRbkmhJK90x4cH'}, {'Artista': 'Juanes', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Fijate Bien', 'Año': '2000', 'ID': '3wE4fvPhhScUAhY37TDc1D'}, {'Artista': 'Alejandro Sanz', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Me iré', 'Año': '2000', 'ID': '42t0ZnBaS3dYFcs3xyQF2Y'}, {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Salomé', 'Año': '2000', 'ID': '4l8i9h5PNoJte95Es3HftJ'}, {'Artista': 'Rodrigo', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Que Ironia', 'Año': '2000', 'ID': '0E9YlthbJZ6WOPKi3LTBJc'}, {'Artista': 'Chayanne', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Mariana Mambo', 'Año': '2000', 'ID': '3ppKW2voPfRuCtdWhF1R9z'}, {'Artista': 'Armando Manzanero', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Esperaré (feat. Café Quijano)', 'Año': '2000', 'ID': '4RclcYWxQMRsdmT25OK9ic'}, {'Artista': 'Donato Y Estefano', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Sin Ti', 'Año': '2000', 'ID': '3c9KuwSygZBPj6gbXLxRc7'}, {'Artista': 'Alejandro Sanz', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Hay un universo de pequeñas cosas', 'Año': '2000', 'ID': '5JA04DokXsoCNcVPI9NRmD'}, {'Artista': 'Rodrigo', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Amor Clasificado', 'Año': '2000', 'ID': '5MK642wCaNr9hRDZ3kWyDX'}, {'Artista': 'Andrés Cepeda', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Sé Morir - Balada Pop', 'Año': '2000', 'ID': '44enjEo4b4JORFCXve6dWZ'}, {'Artista': 'La Oreja de Van Gogh', 'Género': 'latin pop', 'Tipo': 'track', 'Nombre': 'Ta ...

# %%
df_latin_pop = pd.DataFrame(lista_latin_pop)

df_latin_pop
# Out:
#                   Artista     Género   Tipo                          Nombre  \
# 0    La Oreja de Van Gogh  latin pop  track                             Pop
# 1                  Thalia  latin pop  track     Entre El Mar Y Una Estrella
# 2            Ricky Martin  latin pop  track     She Bangs - Spanish Version
# 3                  Thalia  latin pop  track                    Regresa A Mi
# 4           Paulina Rubio  latin pop  track                  Tal Vez Quizas
# ..                    ...        ...    ...                             ...
# 745              Miranda!  latin pop  track                             Don
# 746        Alejandro Sanz  latin pop  track                        12 por 8
# 747                Juanes  latin pop  track                 No Siento Penas
# 748          Damas Gratis  latin pop  track  Popurri / El Ganador - En Vivo
# 749        Alejandro Sanz  latin pop  track      Y sólo se me ocurre amarte
#
#       Año                      ID
# 0    2000  4FXSEdmbbeGmPIQltH27C8
# 1    2000  2KNtKG2X0jpOIgVunVbAkQ
# 2    2000  4ti5pZ0zs1PDf1eQswskFB
# 3    2000  36GbwUTkCSQ18aysIFYEPF
# 4    2000  4Ft4AbNwk1acKagaBOmvHb
# ..    ...                     ...
# 745  2004  4q7gVEuLB1FtIaxGYccUFy
# 746  2004  0dTJZki1VPSGv1uGc68YMP
# 747  2004  3zp8biuxpZSXqkDXAX6StU
# 748  2004  2vVQgTGlENx1znBphTIX3Z
# 749  2004  3zvnloMEkCiIFRsZDUJPaW
#
# [750 rows x 6 columns]
