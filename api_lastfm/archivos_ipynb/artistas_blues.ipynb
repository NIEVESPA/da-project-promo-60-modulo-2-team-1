# %%
import requests
import json
import pandas as pd

# %%
cliente = "micliente"
secreto = "misecreto"

# %%
url_api = "http://ws.audioscrobbler.com/2.0/"

# %%
def llamar_lastfm_api(method, artist_name, cliente):

        params = {'method': method,'artist': artist_name,'api_key': cliente,'format': 'json'}

        response = requests.get(url_api, params=params)


        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error {response.status_code}: No se pudo obtener la información para el método {method}")
            return

# %%
artistas_a_consultar_prueba = ["Greg Brown", "James Intveld", "Joe Bonamassa", "Sean Costello",  "Eric Clapton"]
lista_artistas_prueba = []


for nombre_artista in artistas_a_consultar_prueba:
    print(f"--- Consultando: {nombre_artista} ---")
    
    datos_artista = llamar_lastfm_api('artist.getinfo', nombre_artista, cliente)  
    
    
    if datos_artista and 'artist' in datos_artista:
        
        artista_data = datos_artista['artist']
        
        
        oyentes = artista_data.get('stats', {}).get('listeners', 'arista no encontrado') 
        reproducciones = artista_data.get('stats', {}).get('playcount', 'N/D')
        
        bio_content = artista_data.get('bio', {}).get('content', '')
        
        if not bio_content or bio_content.strip() == "":
            bio_resumen = 'biografia no encontrada'
        else:
            bio_resumen = artista_data.get('bio', {}).get('summary')
        
        lista_artistas_dict = {'artista': artista_data.get('name', nombre_artista),'oyentes': oyentes, 'reproducciones': reproducciones, 'bio_resumen': bio_resumen}
        lista_artistas_prueba.append(lista_artistas_dict)
        
        print(f"Datos de {nombre_artista} procesados y guardados.")
           
    else:
        print(f"No se pudo obtener información de {nombre_artista}")
# Out:
# --- Consultando: Greg Brown ---
# Datos de Greg Brown procesados y guardados.
# --- Consultando: James Intveld ---
# Datos de James Intveld procesados y guardados.
# --- Consultando: Joe Bonamassa ---
# Datos de Joe Bonamassa procesados y guardados.
# --- Consultando: Sean Costello ---
# Datos de Sean Costello procesados y guardados.
# --- Consultando: Eric Clapton ---
# Datos de Eric Clapton procesados y guardados.

# %%
lista_artistas_prueba
# Out:
# [{'artista': 'Greg Brown',
#   'oyentes': '91255',
#   'reproducciones': '1141017',
#   'bio_resumen': 'Greg Brown is a folk musician from Iowa, USA. His "Iowa Waltz" has been (unsuccessfully) proposed to replace the state song of Iowa.\n\nDuring the 1980s, his reputation was established through frequent touring and recurring performances on A Prairie Home Companion. Subsequently, his work has been nominated for Grammy awards. He also founded his own record label and named it Red House Records after a home he lived in in Iowa.  Red House Records is an independent record label specializing in folk music, based in St. <a href="https://www.last.fm/music/Greg+Brown">Read more on Last.fm</a>'},
#  {'artista': 'James Intveld',
#   'oyentes': '20989',
#   'reproducciones': '192278',
#   'bio_resumen': '\nA native of Los Angeles, he started his career at an early age listening and singing along to his parents\' recordings of Hank Williams, Sr., Dean Martin, Lefty Frizzell, and Elvis. By high school he was playing in cover bands and was soon a regular sitting in with the house band at the legendary Palomino Club.\n\nInitially, Intveld worked with his younger brother Ricky and friend Pat Woodward in a band known as the Rockin\' Shadows. The group dissolved <a href="https://www.last.fm/music/James+Intveld">Read more on Last.fm</a>'},
#  {'artista': 'Joe Bonamassa',
#   'oyentes': '475577',
#   'reproducciones': '13852116',
#   'bio_resumen': 'Joe Bonamassa (born May 8, 1977) is an American blues rock  guitarist, singer and songwriter.\n\nBonamassa was born in Utica, New York. He started playing guitar at age four, encouraged by his father, who was an avid music fan and exposed him to British blues rock records by Eric Clapton and Jeff Beck, greatly inspiring him. At 11 years old Joe was mentored and trained by American guitar legend, Danny Gatton. When he was 12 years old, he had his own band called Smokin\' Joe Bonamassa <a href="https://www.last.fm/music/Joe+Bonamassa">Read more on Last.fm</a>'},
#  {'artista': 'Sean Costello',
#   'oyentes': '12642',
#   'reproducciones': '155294',
#   'bio_resumen': 'April 16, 1979-April 15, 2008\n\nBorn in Philadelphia, Costello began playing guitar at age nine, about the time his family moved to Atlanta. He came of age early, appearing regularly in clubs before he could drive, much less gain legal admission, to them. At age 14, his winning performance in the finals of the Memphis Blues Society’s talent competition had career-changing effects. First, it netted him studio time to record his debut album, Call The Cops, a collection of 1940s and 1950s-style Chicago blues. <a href="https://www.last.fm/music/Sean+Costello">Read more on Last.fm</a>'},
#  {'artista': 'Eric Clapton',
#   'oyentes': '3345918',
#   'reproducciones': '79870206',
#   'bio_resumen': 'Eric Patrick Clapton CBE (born 30 March 1945) is an English rock and blues guitarist, singer, and songwriter. He is regarded as one of the most successful and influential guitarists in rock music. He ranked second in Rolling Stone\'s list of the "100 Greatest Guitarists of All Time" and fourth in Gibson\'s "Top 50 Guitarists of All Time". In 2023, Rolling Stone named Clapton the 35th best guitarist of all time. He was also named number five in Time magazine\'s list of "The 10 Best Electric Guitar Players" in 2009. <a href="https://www.last.fm/music/Eric+Clapton">Read more on Last.fm</a>'}]

# %%
datos_artista.keys()
# Out:
# dict_keys(['artist'])

# %%
datos_artista['artist'].keys()
# Out:
# dict_keys(['name', 'mbid', 'url', 'image', 'streamable', 'ontour', 'stats', 'similar', 'tags', 'bio'])

# %%
datos_artista['artist']['bio']
# Out:
# {'links': {'link': {'#text': '',
#    'rel': 'original',
#    'href': 'https://last.fm/music/Eric+Clapton/+wiki'}},
#  'published': '11 Feb 2006, 05:06',
#  'summary': 'Eric Patrick Clapton CBE (born 30 March 1945) is an English rock and blues guitarist, singer, and songwriter. He is regarded as one of the most successful and influential guitarists in rock music. He ranked second in Rolling Stone\'s list of the "100 Greatest Guitarists of All Time" and fourth in Gibson\'s "Top 50 Guitarists of All Time". In 2023, Rolling Stone named Clapton the 35th best guitarist of all time. He was also named number five in Time magazine\'s list of "The 10 Best Electric Guitar Players" in 2009. <a href="https://www.last.fm/music/Eric+Clapton">Read more on Last.fm</a>',
#  'content': 'Eric Patrick Clapton CBE (born 30 March 1945) is an English rock and blues guitarist, singer, and songwriter. He is regarded as one of the most successful and influential guitarists in rock music. He ranked second in Rolling Stone\'s list of the "100 Greatest Guitarists of All Time" and fourth in Gibson\'s "Top 50 Guitarists of All Time". In 2023, Rolling Stone named Clapton the 35th best guitarist of all time. He was also named number five in Time magazine\'s list of "The 10 Best Electric Guitar Players" in 2009.\n\nAfter playing in a number of different local bands, Clapton joined the Yardbirds from 1963 to 1965, and John Mayall & the Bluesbreakers from 1965 to 1966. After leaving Mayall, he formed the power trio Cream with drummer Ginger Baker and bassist/vocalist Jack Bruce, in which Clapton played sustained blues improvisations and "arty, blues-based psychedelic pop". After four successful albums, Cream broke up in November 1968. Clapton then formed the blues rock band Blind Faith with Baker, Steve Winwood, and Ric Grech, recording one album and performing on one tour before they broke up. Clapton then toured with Delaney & Bonnie and recorded his first solo album in 1970, before forming Derek and the Dominos with Bobby Whitlock, Carl Radle and Jim Gordon. Like Blind Faith, the band only lasted one album, Layla and Other Assorted Love Songs, which includes "Layla", one of Clapton\'s signature songs.\n\nClapton continued to record a number of successful solo albums and songs over the next several decades, including a 1974 cover of Bob Marley\'s "I Shot the Sheriff" (which helped reggae reach a mass market), the country-infused Slowhand album (1977) and the pop rock of 1986\'s August. Following the death of his son Conor in 1991, Clapton\'s grief was expressed in the song "Tears in Heaven", which appeared on his Unplugged album. In 1996 he had another top-40 hit with the R&B crossover "Change the World". In 1998, he released the Grammy award-winning "My Father\'s Eyes". Since 1999, he has recorded a number of traditional blues and blues rock albums and hosted the periodic Crossroads Guitar Festival. His most recent studio album is Happy Xmas (2018).\n\nClapton has received 18 Grammy Awards as well as the Brit Award for Outstanding Contribution to Music. In 2004, he was awarded a CBE for services to music. He has received four Ivor Novello Awards from the British Academy of Songwriters, Composers and Authors, including the Lifetime Achievement Award. He is the only three-time inductee to the Rock and Roll Hall of Fame: once as a solo artist, and separately as a member of the Yardbirds and of Cream. In his solo career, he has sold more than 280 million records worldwide, making him one of the best-selling musicians of all time. In 1998, Clapton, a recovering alcoholic and drug addict, founded the Crossroads Centre on Antigua, a medical facility for those recovering from substance abuse. <a href="https://www.last.fm/music/Eric+Clapton">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'}

# %%
datos_artista['artist']['bio']['content']
# Out:
# 'Eric Patrick Clapton CBE (born 30 March 1945) is an English rock and blues guitarist, singer, and songwriter. He is regarded as one of the most successful and influential guitarists in rock music. He ranked second in Rolling Stone\'s list of the "100 Greatest Guitarists of All Time" and fourth in Gibson\'s "Top 50 Guitarists of All Time". In 2023, Rolling Stone named Clapton the 35th best guitarist of all time. He was also named number five in Time magazine\'s list of "The 10 Best Electric Guitar Players" in 2009.\n\nAfter playing in a number of different local bands, Clapton joined the Yardbirds from 1963 to 1965, and John Mayall & the Bluesbreakers from 1965 to 1966. After leaving Mayall, he formed the power trio Cream with drummer Ginger Baker and bassist/vocalist Jack Bruce, in which Clapton played sustained blues improvisations and "arty, blues-based psychedelic pop". After four successful albums, Cream broke up in November 1968. Clapton then formed the blues rock band Blind Faith with Baker, Steve Winwood, and Ric Grech, recording one album and performing on one tour before they broke up. Clapton then toured with Delaney & Bonnie and recorded his first solo album in 1970, before forming Derek and the Dominos with Bobby Whitlock, Carl Radle and Jim Gordon. Like Blind Faith, the band only lasted one album, Layla and Other Assorted Love Songs, which includes "Layla", one of Clapton\'s signature songs.\n\nClapton continued to record a number of successful solo albums and songs over the next several decades, including a 1974 cover of Bob Marley\'s "I Shot the Sheriff" (which helped reggae reach a mass market), the country-infused Slowhand album (1977) and the pop rock of 1986\'s August. Following the death of his son Conor in 1991, Clapton\'s grief was expressed in the song "Tears in Heaven", which appeared on his Unplugged album. In 1996 he had another top-40 hit with the R&B crossover "Change the World". In 1998, he released the Grammy award-winning "My Father\'s Eyes". Since 1999, he has recorded a number of traditional blues and blues rock albums and hosted the periodic Crossroads Guitar Festival. His most recent studio album is Happy Xmas (2018).\n\nClapton has received 18 Grammy Awards as well as the Brit Award for Outstanding Contribution to Music. In 2004, he was awarded a CBE for services to music. He has received four Ivor Novello Awards from the British Academy of Songwriters, Composers and Authors, including the Lifetime Achievement Award. He is the only three-time inductee to the Rock and Roll Hall of Fame: once as a solo artist, and separately as a member of the Yardbirds and of Cream. In his solo career, he has sold more than 280 million records worldwide, making him one of the best-selling musicians of all time. In 1998, Clapton, a recovering alcoholic and drug addict, founded the Crossroads Centre on Antigua, a medical facility for those recovering from substance abuse. <a href="https://www.last.fm/music/Eric+Clapton">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'

# %%
df = pd.read_csv("df_blues.csv")

# %%
df
# Out:
#                      Artista Género   Tipo                        Nombre  \
# 0                 Greg Brown  blues  track                      Blue Car
# 1              James Intveld  blues  track                    Love Calls
# 2             Murali Coryell  blues  track  Softly Let Me Kiss Your Lips
# 3              Joe Bonamassa  blues  track            Miss You, Hate You
# 4              Sean Costello  blues  track                Double Trouble
# ..                       ...    ...    ...                           ...
# 745            Mark Knopfler  blues  track         Song For Sonny Liston
# 746  Muddy Waters Blues Band  blues  track   Everything Gonna Be Alright
# 747          Carl Weathersby  blues  track                       Hold On
# 748          Albert Cummings  blues  track   Blues Makes Me Feel So Good
# 749            Jools Holland  blues  track    St. James' Infirmary Blues
#
#       Año                      ID
# 0    2000  3gIRDIOGmLc1WBhlcv35O5
# 1    2000  3x5EuJxLpjk0vIV5iMpd1i
# 2    2000  5cDIbJtehjhImG8eytKwGw
# 3    2000  270fcAQl6cPF3S3ZQiPNon
# 4    2000  0DeGKiRiCK6Hv8ivuojSdH
# ..    ...                     ...
# 745  2004  7CEB9EWKgL5kC1HTO8Oru7
# 746  2004  5VK783FVcaNdsx5iN0O7dN
# 747  2004  6hvJliJvOMHiKSXjPyUoZf
# 748  2004  5T1sj4W2NIUlbmZMdZmAI3
# 749  2004  6TSgebnc69Ndnw52rffHJV
#
# [750 rows x 6 columns]

# %%
df['Artista']
# Out:
# 0                   Greg Brown
# 1                James Intveld
# 2               Murali Coryell
# 3                Joe Bonamassa
# 4                Sean Costello
#                 ...
# 745              Mark Knopfler
# 746    Muddy Waters Blues Band
# 747            Carl Weathersby
# 748            Albert Cummings
# 749              Jools Holland
# Name: Artista, Length: 750, dtype: object

# %%
artista = df['Artista']

# %%
artista_unico = set(artista)

# %%
artista_unico
# Out:
# {'Aerosmith',
#  'Alabama 3',
#  'Albert Cummings',
#  "Albert Lee & Hogan's Heroes",
#  'Alicia Keys',
#  'Allman Brothers Band',
#  'Alvin Lee',
#  'Amy Winehouse',
#  'Ana Popovic',
#  'Andy Lee Lang',
#  'Ann Nesby',
#  'Art Blakey & The Jazz Messengers',
#  'Arthur "Big Boy" Crudup',
#  'B.B. King',
#  'Barbra Streisand',
#  'Ben B. Beckendorf',
#  'Benny Neyman',
#  'Bessie Smith',
#  'Big Bill Broonzy',
#  'Big Mama Thornton',
#  "Bill Wyman's Rhythm Kings",
#  'Billie Holiday',
#  'Blue Stew',
#  'Blues Company',
#  'Bobby Wayne',
#  'Bonnie Raitt',
#  'Brad Paisley',
#  'Buddaheads',
#  'Buddy Guy',
#  'Byther Smith',
#  'C.C. Adcock',
#  'CHRISTIAN PADOVAN',
#  'Calvin Russell',
#  'Carl Weathersby',
#  'Cave Catt Sammy',
#  'Champion Jack Dupree',
#  'Charlie Parker',
#  'Chet Atkins',
#  'Chick Willis',
#  'Chris Smither',
#  'Chris Thomas King',
#  'Clarence "Gatemouth" Brown',
#  'Coco Montoya',
#  'Coen Wolters Band',
#  'Dany Brillant',
#  'David "Honeyboy" Edwards',
#  'David Gogo',
#  'De-Phazz',
#  'Debbie Davies',
#  'Deborah Coleman',
#  'Delbert McClinton',
#  'Denise LaSalle',
#  'Dick Brave & The Backbeats',
#  'Don Vilanova Botafogo',
#  'Doyle Bramhall',
#  'Doyle Bramhall II',
#  'Dr. Feelgood',
#  'Dr. John',
#  'Earl King',
#  'Eddie Hope',
#  'Eddy Wilsons Blues Band',
#  'Ellis Hall',
#  'Elmore James',
#  'Elvis Presley',
#  'Eric Bibb',
#  'Eric Burdon',
#  'Eric Clapton',
#  'Eric Sardinas',
#  'Esther Phillips',
#  'Etta James',
#  'Freddie King',
#  'Free',
#  'Gary Moore',
#  'George Thorogood & The Destroyers',
#  'Gomez',
#  "Gov't Mule",
#  'Grant Green',
#  'Greg Brown',
#  'Guitar Shorty',
#  'Guru',
#  'Guy Davis',
#  'Hanne Boel',
#  'Heaven & Earth',
#  'Heidi Hauge',
#  'Horace Silver',
#  "Howlin' Wolf",
#  'Ivory Joe Hunter',
#  'J. B. Hutto',
#  'J.B. Lenoir',
#  'James Intveld',
#  'Jamie Cullum',
#  'Jeffrey Foucault',
#  'Jimmie Vaughan',
#  'Jimmy "T99" Nelson',
#  'Jimmy LaFave',
#  'Jimmy Rogers',
#  'Jimmy Smith',
#  'Jimmy Thackery',
#  'Jimmy Thackery And The Drivers',
#  'Joe Bonamassa',
#  'Joe Cocker',
#  'Joe Dassin',
#  'John Hammond',
#  'John Littlejohn',
#  'John Mayall',
#  'John Mayall & The Bluesbreakers',
#  'Johnny & The Jailbirds',
#  'Johnny Boyd',
#  "Johnny Burnette & The Rock 'N' Roll Trio",
#  'Johnny Nicholas',
#  'Johnny Winter',
#  'Jools Holland',
#  'Juicy Lucy',
#  'Julian Sas',
#  'Junior Wells',
#  "Keb' Mo'",
#  'Keith Urban',
#  'Kieran Kane',
#  'Kirk Fletcher',
#  'Koko Taylor',
#  'La Mississippi',
#  'Lead Belly',
#  'Lee Rocker',
#  'Lighthouse Family',
#  "Lightnin' Hopkins",
#  'Lil Ed & The Blues Imperials',
#  'Little Milton',
#  'Lonnie Brooks',
#  'Los DelTonos',
#  'Los Lonely Boys',
#  'Lucille Bogan',
#  'Lucky Lloyd',
#  'Lucky Peterson',
#  'Luther Allison',
#  'Luther Johnson',
#  'Magic Sam',
#  'Magic Slim',
#  'Magic Slim & The Teardrops',
#  'Marc Broussard',
#  'Marcia Ball',
#  'Mario Bradley',
#  'Mark Knopfler',
#  'Mark Selby',
#  'Mem Shannon',
#  'Memphis La Blusera',
#  'Michael Bublé',
#  'Michael Burks',
#  'Mighty Mo Rodgers',
#  'Mighty Sam McClain',
#  'Mike Sanchez',
#  'Mississippi John Hurt',
#  'Mitch Woods and His Rocket 88‘S',
#  'Mojo Blues Band',
#  'Monkey Beat',
#  'Mr. Airplane Man',
#  'Ms. Lauryn Hill',
#  'Muddy Waters',
#  'Muddy Waters Blues Band',
#  'Murali Coryell',
#  'Nappy Brown',
#  'Nick Moss & The Flip Tops',
#  'Nina Simone',
#  'Nitty Gritty Dirt Band',
#  'Norah Jones',
#  'Otis Taylor',
#  'Patrick Yandall',
#  'Peter Green Splinter Group',
#  'Popa Chubby',
#  'R.L. Burnside',
#  'RJD2',
#  'Randy Crawford',
#  'Rascal Flatts',
#  'Ray Bonneville',
#  'Ray Charles',
#  "Ray Collins' Hot Club",
#  'Red Stick Ramblers',
#  'Rob Tognoni',
#  'Robben Ford',
#  'Robert Belfour',
#  'Robert Cray',
#  'Robert Johnson',
#  'Robert Randolph & The Family Band',
#  'Rod Stewart',
#  'Rory Gallagher',
#  'Rusty Zinn',
#  'Ruth Brown',
#  'SEATBELTS',
#  'Saffire-The Uppity Blues Women',
#  'Sam Cooke',
#  'Sam Myers',
#  'Sammy Price',
#  'Santana',
#  'Sean Costello',
#  'Shemekia Copeland',
#  'Simon Crashly & The Roadmasters',
#  'Sista Monica',
#  'Sister Rosetta Tharpe',
#  'Sister Swing',
#  'Slim Harpo',
#  'Snowy White',
#  'Soledad Brothers',
#  'Solomon Burke',
#  'Son House',
#  'Son Seals',
#  'Sonny Boy Williamson I',
#  'Sonny Rollins',
#  'Stan Webb',
#  'Status Quo',
#  'Steve Vaus',
#  'Stevie Ray Vaughan',
#  'Sue Foley',
#  'Susan Tedeschi',
#  'Tab Benoit',
#  'Tadg Galleran',
#  'Ten Years After',
#  'The Band',
#  'The Beat Daddys',
#  'The Bel-Aires',
#  'The Bellfuries',
#  'The Black Keys',
#  'The Blues Brothers',
#  'The Brian Setzer Orchestra',
#  'The Crew Cuts',
#  'The Derek Trucks Band',
#  'The Ditty Bops',
#  'The Holmes Brothers',
#  'The Hoodoo Kings',
#  'The Inmates',
#  'The Limp Twins',
#  'The Nimmo Brothers',
#  'The Notorious Cherry Bombs',
#  'The Quantic Soul Orchestra',
#  'The Refreshments',
#  'The Robert Cray Band',
#  'The Rolling Stones',
#  'The White Stripes',
#  'Tom Waits',
#  'Tommy Castro',
#  'Tommy Johnson',
#  'Tony Bennett',
#  'Twelve Bar Blues Band',
#  'Uriah Heep',
#  'Vargas Blues Band',
#  'W.C. Clark',
#  'Walter Trout and The Free Radicals',
#  'Wes Montgomery',
#  'Wynonie Harris',
#  'Xavier Rudd',
#  'ZZ Top',
#  'Zucchero'}

# %%
len(artista_unico)
# Out:
# 250

# %%
artistas_a_consultar = artista_unico
lista_artistas = []


for nombre_artista in artistas_a_consultar:
    
    datos_artista = llamar_lastfm_api('artist.getinfo', nombre_artista, cliente)  
    
    
    if datos_artista and 'artist' in datos_artista:
        
        artista_data = datos_artista['artist']
        
        
        oyentes = artista_data.get('stats', {}).get('listeners', 'arista no encontrado') 
        reproducciones = artista_data.get('stats', {}).get('playcount', 'N/D')
        
        bio_content = artista_data.get('bio', {}).get('content', '')
        
        if not bio_content or bio_content.strip() == "":
            bio_resumen = 'biografia no encontrada'
        else:
            bio_resumen = artista_data.get('bio', {}).get('summary')
        
        lista_artistas_dict = {'artista': artista_data.get('name', nombre_artista),'oyentes': oyentes, 'reproducciones': reproducciones, 'bio_resumen': bio_resumen}
        lista_artistas.append(lista_artistas_dict)
        
    
           
    else:
        print(f"No se pudo obtener información de {nombre_artista}")

# %%
# --- 1. DICCIONARIO BASE (PAÍS: GENTILICIO) ---
# Usamos el diccionario que generamos previamente:
PAIS_A_GENTILICIO = {
    "Afghanistan": "Afghan",
    "Albania": "Albanian",
    "Algeria": "Algerian",
    "Argentina": "Argentinian",
    "Australia": "Australian",
    "Austria": "Austrian",
    "Belgium": "Belgian",
    "Bolivia": "Bolivian",
    "Brazil": "Brazilian",
    "Canada": "Canadian",
    "Chile": "Chilean",
    "China": "Chinese",
    "Colombia": "Colombian",
    "Costa Rica": "Costa Rican",
    "Cuba": "Cuban",
    "Denmark": "Dane",
    "Egypt": "Egyptian",
    "France": "French",
    "Germany": "German",
    "Greece": "Greek",
    "India": "Indian",
    "Indonesia": "Indonesian",
    "Ireland": "Irish",
    "Italy": "Italian",
    "Jamaica": "Jamaican",
    "Japan": "Japanese",
    "Mexico": "Mexican",
    "Netherlands": "Dutch",
    "New Zealand": "New Zealander",
    "Nigeria": "Nigerian",
    "Norway": "Norwegian",
    "Peru": "Peruvian",
    "Poland": "Pole",
    "Portugal": "Portuguese",
    "Russia": "Russian",
    "South Korea": "South Korean",
    "Spain": "Spaniard",
    "Sweden": "Swede",
    "Turkey": "Turk",
    "Ukraine": "Ukrainian",
    "United Kingdom": "Briton",
    "United States": "American",
    "United States_adj": "American",
    "United Kingdom_adj": "British",
    "France_adj": "French",
    "Germany_adj": "German",
    "Spain_adj": "Spanish"}
# --- 2. DICCIONARIO INVERTIDO PARA BÚSQUEDA EFICIENTE ---
# Clave: Gentilicio (lo que busco en la bio), Valor: País
GENTILICIO_A_PAIS = {gentilicio.lower(): pais.replace('_adj', '')
    for pais, gentilicio in PAIS_A_GENTILICIO.items()}

# %%
def extraer_pais_de_biografia(bio_resumen, gentilicio_a_pais_map):
    bio_normalizada = bio_resumen.lower()
    for gentilicio, pais in gentilicio_a_pais_map.items():
        # Usamos ' ' + gentilicio + ' ' para buscar la palabra completa y evitar coincidencias parciales
        if f' {gentilicio} ' in bio_normalizada or bio_normalizada.startswith(f'{gentilicio} '):
            return pais
        # Caso especial para "is an American rock band" (no tiene espacio antes)
        if bio_normalizada.endswith(gentilicio):
             return pais
    return 'Unknown'

# %%
for artista_data in lista_artistas:
    bio = artista_data['bio_resumen']
    pais_encontrado = extraer_pais_de_biografia(bio, GENTILICIO_A_PAIS)
    artista_data['pais'] = pais_encontrado #aqui agregamos la clave pais en nuestro diccionario

# %%
lista_artistas
# Out:
# [{'artista': 'W.C. Clark',
#   'oyentes': '9252',
#   'reproducciones': '41127',
#   'bio_resumen': 'W.C. Clark (born Wesley Curley Clark in Austin, TX, on 16 November 1939; died 2 March 2024) was an American blues musician remembered as the "Godfather of Austin Blues" for his influence on the Austin, TX, blues scene since the late 1960s. \n\nIn the late 1960s, Clark joined the Joe Tex band. After forming several bands with various names, Clark formed the W.C. Clark Blues Revue in 1975. \n\n“Modern Texas blues at its best…impeccable, soothing soul and flashy <a href="https://www.last.fm/music/W.C.+Clark">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Chet Atkins',
#   'oyentes': '293379',
#   'reproducciones': '3200761',
#   'bio_resumen': 'Chester Burton Atkins born 20 June 1924 - Died 30 June 2001 in Nashville, Tennessee, United States (1942–1996) . was an American guitarist and record producer. Together with Owen Bradley, Atkins created the smoother country music style known as the Nashville sound, which expanded country music\'s appeal to include adult pop music fans as well. His virtuoso picking style - inspired by Merle Travis, Django Reinhardt, George Barnes and Les Paul - brought him admirers both within and outside the country scene. <a href="https://www.last.fm/music/Chet+Atkins">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Sue Foley',
#   'oyentes': '36605',
#   'reproducciones': '313880',
#   'bio_resumen': 'Sue Foley (born March 29, 1968, Ottawa, Ontario, Canada) is a Canadian blues singer and guitarist. She has also recorded as Peter Karp & Sue Foley. \n\nSince her first album in 1992  Foley has recorded a string of albums, for both Antone\'s Records and Shanachie Records. She has spent many years on the road as a bandleader, lead vocalist, guitarist and manager of her own band. In addition to her own touring, she has also shared the stage with blues musicians such as Back Alley John, B. B. King, Buddy Guy and John Lee Hooker.  <a href="https://www.last.fm/music/Sue+Foley">Read more on Last.fm</a>',
#   'pais': 'Canada'},
#  {'artista': 'Ellis Hall',
#   'oyentes': '5471',
#   'reproducciones': '24534',
#   'bio_resumen': 'Ellis Hall Jr. (born May 10, 1951 in Savannah, Georgia) known professionally as Ellis Hall is an American singer-songwriter, multi-instrumentalist, actor and composer. He was described as "The Ambassador of Soul" by conductor, Jeff Tyzik. Hall has been blind since the age of 18. Citing Ray Charles as his inspiration, Hall has written over 4000 soul, gospel, blues and pop songs,[1] and has performed with Stevie Wonder, James Taylor, Natalie Cole, Patti LaBelle <a href="https://www.last.fm/music/Ellis+Hall">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'The Limp Twins',
#   'oyentes': '136255',
#   'reproducciones': '998008',
#   'bio_resumen': 'The Limp Twins are Will Holland (a.k.a quantic) and Russell Porter, who created their album tales from beyond the groove (TRUCD057, 2003) in their bedrooms (according to the cd cover). The record is a funky offering somewhere in between the sound of Will Holland\'s other projects, quantic and the quantic soul orchestra, but is definately more laid back. \n\nFor more information on this project, check out quantic\'s website: about The Limp Twins. <a href="https://www.last.fm/music/The+Limp+Twins">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Jimmy Thackery And The Drivers',
#   'oyentes': '17489',
#   'reproducciones': '124417',
#   'bio_resumen': 'Known for his gritty, blue-collar approach and marathon live shows, Thackery was for many years part of The Nighthawks. The Nighthawks were known as one of the hardest-working blues bar bands in North America.[citation needed] Since the late 1980s, Thackery has been touring under his own name, and has found a wide audience. His hard-edged, tough-as-nails approach to guitar playing and his trio\'s driving rhythm section holds appeal for fans of both traditional blues and roots rock. <a href="https://www.last.fm/music/Jimmy+Thackery+And+The+Drivers">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'The Holmes Brothers',
#   'oyentes': '34197',
#   'reproducciones': '197057',
#   'bio_resumen': 'The Holmes Brothers were an American musical trio originally from Christchurch, Virginia.\nMixing sounds from blues, soul, gospel, country, and rhythm & blues, they have released twelve studio albums, with three reaching the top 5 on the Billboard Blues Albums chart. They have gained a following by playing regularly at summer folk, blues, gospel, and jazz festivals. They have recorded with Van Morrison, Peter Gabriel, Odetta, Phoebe Snow, Willie Nelson <a href="https://www.last.fm/music/The+Holmes+Brothers">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'The Rolling Stones',
#   'oyentes': '5674210',
#   'reproducciones': '264639939',
#   'bio_resumen': 'The Rolling Stones is an English rock band formed in London in 1962. Active for six decades, they are one of the most popular and enduring bands of the rock era. In the early 1960s, the Rolling Stones pioneered the gritty, rhythmically driven sound that came to define hard rock. Their first stable line-up consisted of vocalist Mick Jagger, multi-instrumentalist Brian Jones, guitarist Keith Richards, bassist Bill Wyman, and drummer Charlie Watts. During their formative years <a href="https://www.last.fm/music/The+Rolling+Stones">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Jimmy Smith',
#   'oyentes': '426313',
#   'reproducciones': '3706936',
#   'bio_resumen': 'Jimmy Smith (1925–2005) was a jazz musician whose instrument was the Hammond B-3 electric organ.\n\nBorn James Oscar Smith on 8th December 1925 in Norristown, Pennsylvania, USA. Smith was influenced by both gospel and blues. He first achieved prominence in the 1950s where his recordings became popular on jukeboxes before there were commonly used terms to describe his unique musical flavor. In the sixties and seventies he helped create the jazz style known as soul jazz. <a href="https://www.last.fm/music/Jimmy+Smith">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Elvis Presley',
#   'oyentes': '4315393',
#   'reproducciones': '144903841',
#   'bio_resumen': 'Elvis Aaron Presley (January 8, 1935 – August 16, 1977) was an American singer and actor. Regarded as one of the most significant cultural icons of the 20th century, he is often referred to as the "King of Rock and Roll" or simply "the King".\n\nPresley was born in Tupelo, Mississippi, and relocated to Memphis, Tennessee, with his family when he was 13 years old. His music career began there in 1954, recording at Sun Records with producer Sam Phillips, who wanted to bring the sound of African American music to a wider audience. <a href="https://www.last.fm/music/Elvis+Presley">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'J.B. Lenoir',
#   'oyentes': '105961',
#   'reproducciones': '663645',
#   'bio_resumen': 'J. B. Lenoir /ləˈnɔːr/ (Monticello, Mississippi, March 5, 1929  – Urbana, Illinois, April 29, 1967) was an African American blues guitarist and singer-songwriter, active in the 1950s and 1960s Chicago blues scene.\nLenoir\'s guitar-playing father introduced him to the music of Blind Lemon Jefferson, whose music became a major influence. During the early 1940s, Lenoir worked with blues artists Sonny Boy Williamson II and Elmore James in New Orleans. Lenoir would eventually find musical influence in Arthur Crudup and Lightnin\' Hopkins. <a href="https://www.last.fm/music/J.B.+Lenoir">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': "Bill Wyman's Rhythm Kings",
#   'oyentes': '9937',
#   'reproducciones': '216487',
#   'bio_resumen': 'Bill Wyman\'s Rhythm Kings are a blues-rock band founded in 1997 and led by the Rolling Stones\' bass guitarist Bill Wyman. Together with his lifelong musical partner Terry Taylor. This "Dirty Boys" duo produce, arrange and compose original material for the award-winning band. Members of the band, eithering touring or as studio guests, has included such stars as Peter Frampton, Albert Lee, Gary Brooker, Georgie Fame, Andy Fairweather-Low, Mark Knopfler and Martin Taylor. <a href="https://www.last.fm/music/Bill+Wyman%27s+Rhythm+Kings">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Vargas Blues Band',
#   'oyentes': '22103',
#   'reproducciones': '264146',
#   'bio_resumen': '”Javier Vargas was born in Madrid. When he was nine years old, he and his family moved to Argentina, where his parents had lived during the Spanish Civil War. They lived in Mendoza, San Luis, Buenos Aires and also in Mar del Plata, where he started playing the guitar with young musicians in places such as garages. He took guitar lessons, and he also used to go clubs to listen to groups playing blues live.\n\nThe first guitar Vargas had, present from his father, it was a Spanish guitar with naylon strings. <a href="https://www.last.fm/music/Vargas+Blues+Band">Read more on Last.fm</a>',
#   'pais': 'Spain'},
#  {'artista': 'Lighthouse Family',
#   'oyentes': '565149',
#   'reproducciones': '6540576',
#   'bio_resumen': 'Lighthouse Family was a British pop-soul duo formed in 1993 that rose to prominence in the mid-1990s and initially remained active until 2003. The duo reformed during 2010 to 2011 and again from 2019 before splitting in 2022. \n\nThe duo comprised vocalist Tunde Baiyewu (born in London on 25 November 1968) and keyboard player Paul Tucker, (born in London on 12 August 1968) and formed in 1993 in Newcastle upon Tyne, England after meeting at college. Their 1995 debut album "Ocean Drive" sold more than 1. <a href="https://www.last.fm/music/Lighthouse+Family">Read more on Last.fm</a>',
#   'pais': 'United Kingdom'},
#  {'artista': 'Dick Brave & The Backbeats',
#   'oyentes': '54014',
#   'reproducciones': '805885',
#   'bio_resumen': 'Dick Brave & The Backbeats is a rockabilly cover band from germany best known for their electrifing 50s-style performances of pop/rock classics such as Depeche Mode\'s "I Just Can\'t Get Enough", Green Day\'s "American Idiot" or the Queens Of The Stone Age\'s "No One Knows". \n\nThough band leader Dick Brave claims to be canadian, the project actually marks the unlikely evolution of german pop singer Sasha - a frequent guest in the pop charts during the 1990s with hits like I Feel Lonely, If You Believe or Young Deenay\'s Walk On By. <a href="https://www.last.fm/music/Dick+Brave+&+The+Backbeats">Read more on Last.fm</a>',
#   'pais': 'Germany'},
#  {'artista': 'Ms. Lauryn Hill',
#   'oyentes': '1326796',
#   'reproducciones': '35386645',
#   'bio_resumen': 'Lauryn Noelle Hill (born May 26, 1975) is an American rapper, singer, songwriter, record producer, and actress. She is celebrated as one of the most influential musical artists of her generation. Hill is credited with breaking barriers for female rappers, contributing to the mainstream success of both hip-hop and neo soul, and blending rap with melodic vocals. She has been honored as one of the 50 Great Voices by NPR, and one of the 200 Greatest Singers of All Time by Rolling Stone. <a href="https://www.last.fm/music/Ms.+Lauryn+Hill">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Joe Dassin',
#   'oyentes': '523163',
#   'reproducciones': '7352775',
#   'bio_resumen': 'Joseph Ira Dassin (November 5, 1938 - August 20, 1980) was a French-speaking American folk, pop and rock musician.\n\nDassin was born in New York City to Jules Dassin (Yiddish actor and film noir director) and Béatrice Launer. He began his childhood first in New York and Los Angeles, California. However after his father became a victim of the anti-communist policies of Senator Joseph McCarthy, he and his family moved from place to place across Europe. <a href="https://www.last.fm/music/Joe+Dassin">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Ann Nesby',
#   'oyentes': '20294',
#   'reproducciones': '152725',
#   'bio_resumen': 'Formerly the lead vocalist for the 30-piece gospel choir Sounds of Blackness, Ann Nesby struck out on her own in 1996 with an album for the Perspective label, Ann Nesby 1996. With the help of super-producers Jam & Lewis, the R&B-oriented LP scored a hit with "I\'m Here for You." Nesby has contributed to several soundtracks (Batman, Mo\' Money, Demolition Man) and tribute albums (to Curtis Mayfield, Marvin Gaye, John Lennon). She has also won two Grammy awards: one as part of Sounds of Blackness for the 1991 album Evolution of Gospel <a href="https://www.last.fm/music/Ann+Nesby">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': "Johnny Burnette & The Rock 'n' Roll Trio",
#   'oyentes': '48709',
#   'reproducciones': '292140',
#   'bio_resumen': 'Johnny Burnette & The Rock \'n\' Roll Trio was an American rockabilly group formed in Memphis, Tennessee, during the 1950s. Later recordings were attributed to The Johnny Burnette Trio. The members of the Trio were Dorsey Burnette, his younger brother Johnny Burnette, and a friend Paul Burlison. Dorsey and Johnny Burnette were both natives of Memphis, having been born there in 1932 and 1934 respectively. Paul Burlison was born in Brownsville, Tennessee in 1929, but moved to Memphis with his family in 1937. <a href="https://www.last.fm/music/Johnny+Burnette+&+The+Rock+%27n%27+Roll+Trio">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': "Gov't Mule",
#   'oyentes': '297117',
#   'reproducciones': '5745334',
#   'bio_resumen': 'Gov\'t Mule is a southern rock/jam band formed in 1994 as a side project to The Allman Brothers Band, but has taken on a life of its own. Like many jam bands, Gov\'t Mule does not get much radio airplay but is popular due to constant touring and intense fan loyalty. \n\nWhen the Allman Brothers Band reformed in 1989 in response to the popularity of the Dreams box set, Warren Haynes was added on lead guitar and Allen Woody on bass. The two shared a love for \'60s power trios, like Cream, Jimi Hendrix Experience, and James Gang. <a href="https://www.last.fm/music/Gov%27t+Mule">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Patrick Yandall',
#   'oyentes': '11358',
#   'reproducciones': '80845',
#   'bio_resumen': 'Patrick Yandall. Contemporary and smooth jazz guitarist with 14 international releases. He has been featured in Jazziz, Smooth Jazz News, Jazz Times, Guitar Player, and many other print and internet media. A producer and session guitarist based in San Diego, CA. His music has been used in feature film, Television, commercials, Internet media, The Weather Channel, Music Choice, and more! Producer and session musician. Influenced by Larry Carlton, George Benson <a href="https://www.last.fm/music/Patrick+Yandall">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Sista Monica',
#   'oyentes': '1603',
#   'reproducciones': '7736',
#   'bio_resumen': 'Sista Monica Parker, aka the “Lioness of the Blues,” is an award-winning blues, soul, and gospel singer, songwriter, producer, public speaker, director and minister of music. A captivating, dynamic performer, today she is one of the most admired women on the international music and festival scene. \n\nSista Monica started singing as a young girl in the church choir in the Midwest between Chicago, Illinois, Gary, Indiana (her home town) and Detroit, Michigan. <a href="https://www.last.fm/music/Sista+Monica">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Christian Padovan',
#   'oyentes': '4648',
#   'reproducciones': '19259',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Eric Bibb',
#   'oyentes': '120830',
#   'reproducciones': '1454411',
#   'bio_resumen': 'Eric Bibb (b. 1951) is an American blues singer and guitarist, based in London, England, who has made his career largely in Europe.\n\nBibb was born on 16th August 1951 in New York into a musical family. His  father, Leon Bibb, is a trained singer who sang in musical theatre and made a name for himself as part of the 1960s New York folk scene. His uncle was the world-famous jazz pianist and composer John Lewis, of the Modern Jazz Quartet. Family friends included Pete Seeger, Odetta, and actor/singer/activist Paul Robeson, Bibb\'sgodfather. <a href="https://www.last.fm/music/Eric+Bibb">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'The Brian Setzer Orchestra',
#   'oyentes': '320671',
#   'reproducciones': '3873256',
#   'bio_resumen': 'Brian Setzer (born April 10, 1959 in New York) is an American guitarist, singer and songwriter whose popular big band orchestra is most appreciated commercially for their swinging take on Christmas holiday classics.\n\nEarly in his career Setzer was a member of the NYC band Bloodless Pharaohs, and later fronted the popular rockabilly revival band, Stray Cats. The Stray Cats particularly caught America\'s attention with the 1982 album Built for Speed <a href="https://www.last.fm/music/The+Brian+Setzer+Orchestra">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Slim Harpo',
#   'oyentes': '179297',
#   'reproducciones': '1149560',
#   'bio_resumen': 'Slim Harpo (11 January 1924 – 31 January 1970) was a blues musician.\n\nBorn James Moore in Lobdel, Louisiana, the eldest in an orphaned family, Moore worked as a longshoreman and building worker during the late 1930s and early 1940s. One of the foremost proponents of post-war rural blues, he began performing in Baton Rouge bars under the name Harmonica Slim. He later accompanied Lightning Slim, his brother-in-law, both live and in the studio, before commencing his own recording career in 1957. <a href="https://www.last.fm/music/Slim+Harpo">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Los Lonely Boys',
#   'oyentes': '233722',
#   'reproducciones': '2133412',
#   'bio_resumen': 'Los Lonely Boys is an American Chicano rock power trio from San Angelo, Texas. The band formed in 1996 and plays a style of music they call "Texican Rock n\' Roll," combining elements of rock and roll, Texas blues, brown-eyed soul, country, and Tejano. The band consists of three brothers: Henry Garza (guitar, vocals), Jojo Garza (bass, vocals), and Ringo Garza (drums, vocals).\n\nThe three brothers emerged as a group in Nashville in the 1990s. After moving back to their home state of Texas they recorded their debut album in 2003. <a href="https://www.last.fm/music/Los+Lonely+Boys">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Seatbelts',
#   'oyentes': '528836',
#   'reproducciones': '13148882',
#   'bio_resumen': '\n\nシートベルツ (Seatbelts), the name of the band, according to the fictional description given in the anime series Cowboy Bebop, derives from how the performers wear seatbelts to be safe while they play hardcore jam sessions.\n\nThe band performed the whole soundtrack of the anime series Cowboy Bebop and produced a total of seven albums and one live DVD. Their style is very diverse and ranges from straightforward big band jazz, blues, acoustic ballads, hard rock, country, funk to electronic, hip-hop and experimental compositions/elements. <a href="https://www.last.fm/music/+noredirect/Seatbelts">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Stevie Ray Vaughan',
#   'oyentes': '1137189',
#   'reproducciones': '17905282',
#   'bio_resumen': 'Stephen ("Stevie") Ray Vaughan, born in Dallas, Texas (October 3, 1954 – August 27, 1990) was an American blues guitar legend, and is known as one of the most influential blues musicians in history.\n\nStevie Ray had been in numerous bands before joining blues rock combo Stevie Ray Vaughan and Double Trouble in the late 1970\'s.\n \nStevie Ray Vaughan and Double Trouble\'s debut album was released in 1983. The critically acclaimed Texas Flood (1983) featured the top-20 hit Pride and Joy and sold well in both blues and rock circles.  <a href="https://www.last.fm/music/Stevie+Ray+Vaughan">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'John Littlejohn',
#   'oyentes': '5634',
#   'reproducciones': '21082',
#   'bio_resumen': 'John Wesley Funchess (April 16, 1931 – February 1, 1994) known professionally as John (or Johnny) Littlejohn, was an American blues slide guitarist. He was active on the Chicago blues circuit from the 1950s to the 1980s.\n\nBorn in Lake, Mississippi, Littlejohn first learned to play the blues from Henry Martin, a friend of his father. In 1946 he left home and traveled widely, spending time in Jackson, Mississippi, Arkansas, Rochester, New York, and Gary, Indiana. <a href="https://www.last.fm/music/John+Littlejohn">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': "Albert Lee & Hogan's Heroes",
#   'oyentes': '8097',
#   'reproducciones': '44490',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Horace Silver',
#   'oyentes': '523349',
#   'reproducciones': '4367048',
#   'bio_resumen': 'Horace Silver (September 2, 1928 - June 18, 2014) was an American jazz pianist and composer. \nHe is known for his distinctive humorous and funky playing style, and for his pioneering contributions to hard bop. Silver was influenced by a wide range of musical styles, notably gospel music, African music, and Latin American music. Silver began his career as a saxophonist, but later switched to piano. His playing was highly influenced by the style of Bud Powell.  <a href="https://www.last.fm/music/Horace+Silver">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Mark Knopfler',
#   'oyentes': '821170',
#   'reproducciones': '24127457',
#   'bio_resumen': 'Mark Freuder Knopfler, OBE (born 12 August 1949) is a British singer, guitarist, composer, songwriter, record producer, and film score composer. He was the lead guitarist, lead singer, and songwriter for the rock band Dire Straits, which he co-founded with his younger brother, David Knopfler, in 1977. He was born in Glasgow but raised near Newcastle upon Tyne, England.\n\nSince Dire Straits disbanded in 1995, Knopfler has recorded and produced nine solo albums and, as with his previous band, produced many hit songs. <a href="https://www.last.fm/music/Mark+Knopfler">Read more on Last.fm</a>',
#   'pais': 'United Kingdom'},
#  {'artista': 'Cave Catt Sammy',
#   'oyentes': '3474',
#   'reproducciones': '30762',
#   'bio_resumen': 'Hailing from San Antonio, TX since forming in high school in 1997, Cave Catt Sammy exhibit maturation and a darker lyrical content with their self penned material. They also conjure up learned covers by greats such as Jerry Reed ("Your Money Makes You Purty") and Roy Orbison ("Cast Iron Arm", originally recorded for Decca by Peanuts Wilson). No doubt their youthful enthusiasm has been tempered by 5 years of hard national touring and international festival appearances. <a href="https://www.last.fm/music/Cave+Catt+Sammy">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Ana Popovic',
#   'oyentes': '77282',
#   'reproducciones': '935105',
#   'bio_resumen': 'Ana Popović (born May 13, 1976, Belgrade, Serbia) is a blues guitarist, singer and songwriter. Ana has released 5 studio albums as a solo artist; Hush! (2000), Comfort To The Soul (2003), Still Making History (2007), Blind For Love (2009) and Unconditional (2011).\n\nAna Popović\'s father first introduced her to the blues, through an extensive record collection and sessions hosted at the family home. Popović founded her first serious band at age nineteen. <a href="https://www.last.fm/music/Ana+Popovic">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Luther Johnson',
#   'oyentes': '37054',
#   'reproducciones': '147370',
#   'bio_resumen': 'There is more than one artist called Luther Johnson.\n\n1) Luther Johnson (April 11, 1939-) is a Chicago blues singer and guitarist, who performs under the name Luther "Guitar Junior" Johnson. He is not billed as simply "Guitar Junior".\n\nHe was born in Itta Bena, Mississippi, USA in 1939 and moved to Chicago with his family in 1955. During the 1960s, he performed with Magic Sam. Johnson performed in Muddy Water\'s band from 1972 to 1980. In 1980, four of his songs were included on an anthology by Alligator Records. <a href="https://www.last.fm/music/Luther+Johnson">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'C.C. Adcock',
#   'oyentes': '9848',
#   'reproducciones': '79919',
#   'bio_resumen': 'C.C. Adcock (born Charles Clinton Adcock, c. 1971, Lafayette, Louisiana) is a rock and roll musician from noted for his cajun, zydeco, electric blues and swamp pop-influenced sound, and for his efforts to preserve and promote swamp pop music.\n\nAdcock has recorded two solo albums, the self-titled C. C. Adcock (produced by Tarka Cordell), issued in 1994 on the Island label, and reissued in 2000 on the Evangeline label, under the title House Rocker; and Lafayette Marquis, issued in 2004 on the Yep Roc label. <a href="https://www.last.fm/music/C.C.+Adcock">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Heaven & Earth',
#   'oyentes': '12350',
#   'reproducciones': '113929',
#   'bio_resumen': 'There is more than one artist under the name Heaven & Earth.\n\nOne is a soul group from Chicago, Illinois, U.S.A. and released 4 LPs from 1976 to 1981.\n\n>>\nA vocal quartet that originally went by the name the Soul Majestics, and consisted of brothers Dwight Dukes (falsetto/lead tenor) and James Dukes (bass), Keith Steward (tenor) and Michael Brown (baritone). Under the direction of producer Clarence Johnson, they recorded four albums as Heaven Earth: one for General Entertainment Corporation (GEC), three for Mercury (Phonogram) and one for WMOT. <a href="https://www.last.fm/music/Heaven+&+Earth">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Elmore James',
#   'oyentes': '437576',
#   'reproducciones': '3468039',
#   'bio_resumen': 'Elmore James (Elmore Brooks, Richland, Mississippi, 27th January 1918 – Chicago, Illinois, 24th May 1963) was an American blues singer and guitarist. He was known as "The King of the Slide Guitar".\n\nJames was born  fifty miles north of Jackson (not to be confused with another Richland just south of Jackson). He began playing as a teen, under the names "Cleanhead" and "Joe Willie James", alongside musicians such as the first Sonny Boy Williamson, Howlin\' Wolf, and Robert Johnson. <a href="https://www.last.fm/music/Elmore+James">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Rob Tognoni',
#   'oyentes': '11524',
#   'reproducciones': '117756',
#   'bio_resumen': 'Rob Tognoni and his guitar have been treading the stages worldwide for the past 35 years.\nHe has opened for the greats - Roy Buchanan, Stevie Ray Vaughan\'s mentor Lonnie Mack, Joe Walsh from the Eagles, shared stages with Peter Green, Sting, ZZ Top, Bo Diddley. He has represented Australia at the Royal Wedding celebrations of Prince Frederik & Princess Mary of Denmark, performed for FIFA World Cup Football in Kaiserslautern, played from maximum security <a href="https://www.last.fm/music/Rob+Tognoni">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Coen Wolters Band',
#   'oyentes': '3304',
#   'reproducciones': '22180',
#   'bio_resumen': 'Since the release of the band’s latest album "As The Crow Flies" (2006) everything changed for the band. Coen\'s long history of self released CD\'s and continual live performances, cumulating in the release of his debut "Broken Glass" (2005) CD on Cryingtone Records, established him as an up and coming blues slinger with an original twist of his own.\nThe "live band" sound of "as The Crow Flies", coupled with the tours at major festivals that following year <a href="https://www.last.fm/music/Coen+Wolters+Band">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Coco Montoya',
#   'oyentes': '81422',
#   'reproducciones': '729422',
#   'bio_resumen': 'Coco Montoya (b. 1951 in Santa Monica, CA) is a blues guitarist and former member of John Mayall & The Bluesbreakers.\n\nMontoya\'s career began in the mid-70\'s when Albert Collins asked him to join his band as drummer. Collins took Montoya under his wing and taught him his "icy hot" guitar style. The two remained friends even after Montoya left Collins\' band.\n\nIn the early 80\'s John Mayall heard Montoya playing guitar in a Los Angles bar. Soon after Mayall asked Montoya to join the newly reformed Bluesbreakers. <a href="https://www.last.fm/music/Coco+Montoya">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Calvin Russell',
#   'oyentes': '42153',
#   'reproducciones': '467434',
#   'bio_resumen': 'Russell was born in Austin, Texas, on 1 November 1948. At age 12, Russell began learning guitar and at 13 joined a band called The Cavemen. In 1989, he met Patrick Mathe of the French record label, New Rose Records, while at a party in Austin and gave him a demo tape intended for noted Austin guitarist and producer, Charlie Sexton. \n\nHe would go on to sign with the label releasing his first solo album in 1990 entitled A Crack In Time. In promotion of the album <a href="https://www.last.fm/music/Calvin+Russell">Read more on Last.fm</a>',
#   'pais': 'France'},
#  {'artista': 'Lucille Bogan',
#   'oyentes': '50340',
#   'reproducciones': '211828',
#   'bio_resumen': 'Lucille Bogan (April 1, 1897 - August 10, 1948) was an American blues singer, among the first to be recorded. She also recorded under the pseudonym Bessie Jackson. Bogan sang straight-talking blues about drinking ("Sloppy Drunk Blues"), prostitution ("Tricks Ain\'t Walking No More"), gambling, lesbianism and other facets of what her generation called \'the life\'. The jazz critic and sexologist Ernest Borneman grouped her with Ma Rainey and Bessie Smith in the "the big three of the blues". <a href="https://www.last.fm/music/Lucille+Bogan">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Keith Urban',
#   'oyentes': '1092154',
#   'reproducciones': '19990383',
#   'bio_resumen': 'Keith Lionel Urban (born 26 October 1967) is a New Zealand-born country music singer, songwriter and guitarist whose commercial success has been mainly in the United States and Australia. Originally the front man for The Ranch, a three-piece group that released one album in 1997 to critical acclaim, Urban disbanded the group to pursue a solo career.  In 2004 his album "Be Here" was nominated for best country album at the Grammy Awards and at the Academy of Country Music Awards. <a href="https://www.last.fm/music/Keith+Urban">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Tommy Castro',
#   'oyentes': '73110',
#   'reproducciones': '619059',
#   'bio_resumen': 'Tommy Castro (born April 15, 1955) is an American blues, R&B, and rock guitarist and singer. He has been recording since the mid-1990s. His music has taken him from local stages to national and international touring. His popularity was marked by his winning the 2008 Blues Music Award for Entertainer of the Year.[1]\n\nAccording to The Chicago Sun-Times, Castro plays "Memphis soul-drenched R&B…top-of-the-line blues."[2] Tom Callahan of Blurt added, "Castro has a soulful voice, searing guitar and is an excellent songwriter and vocalist. <a href="https://www.last.fm/music/Tommy+Castro">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Kieran Kane',
#   'oyentes': '8700',
#   'reproducciones': '86897',
#   'bio_resumen': 'Kieran Kane (born October 7, 1949 in Queens, New York) is an American country music artist, as well as the owner of Dead Reckoning Records, an independent record label.[1] Between 1986 and 1990, he and Jamie O\'Hara comprised The O\'Kanes, In 1993, Kieran returned to his career as a solo performer. He signed to Atlantic Records that year, releasing the album Find My Way Home. Due to poor sales of this album, he was soon dropped from Atlantic\'s roster. <a href="https://www.last.fm/music/Kieran+Kane">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Lead Belly',
#   'oyentes': '203863',
#   'reproducciones': '1950861',
#   'bio_resumen': 'Huddie Ledbetter (23 January 1888 - December 1949) was a leading American blues singer and guitarist. His songbook contained a large number of standard folk tunes, most adapted from previous sources.\n\nThough many of his posthumous releases list him as "Leadbelly," he himself spelled it "Lead Belly." This is also the usage on most of his original records, tombstone, as well as of the Lead Belly Foundation.\n\nLead Belly was born in Mooringsport, Louisiana, and spent time in and out of prison most of his life. <a href="https://www.last.fm/music/+noredirect/Lead+Belly">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'The Robert Cray Band',
#   'oyentes': '73070',
#   'reproducciones': '650389',
#   'bio_resumen': 'Robert Cray is an American blues guitarist, composer and singer.\nWith bassist Richard Cousins, keyboardist Peter Boe and drummer Tom Murphy, they launched The Robert Cray Band in 1980 with "Who\'s Been Talkin". The album was recorded during constant touring in the U.S. in 1978. The record was initially shelved for two years, being eventually issued by the short-lived Tomato label (whose licence was picked up by "Atlantic Records" (U.S.) and "Charly" in the UK. <a href="https://www.last.fm/music/The+Robert+Cray+Band">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'The Hoodoo Kings',
#   'oyentes': '674',
#   'reproducciones': '2204',
#   'bio_resumen': 'In bringing together elder bluesmen Eddie Bo (died in 2009), Raful Neal (died in 2004) and Rockin’ Tabby Thomas (died in 2014) with a band of younger cohorts, The Hoodoo Kings captured the simmering essence of Louisiana. Hoodoo Kings was produced in 2001 by Randy Labbe, and their backing band consisted of guitarists Greg Hoover and Denny Breau, bassist Dan Corbett, drummer Darren Thiboutot and backup vocalist Kelly Jones. On their Telarc release <a href="https://www.last.fm/music/The+Hoodoo+Kings">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Byther Smith',
#   'oyentes': '36927',
#   'reproducciones': '213256',
#   'bio_resumen': 'Byther Smith is a true Living Legend of the Chicago blues scene and during his long lasting career he worked with the greatest of the Chicago blues artists like Muddy Waters, Howlin\' Wolf, Jimmy Reed and Otis Rush.\n\nBorn in Monticello, Mississippi on April 17, 1933 young Byther Smith got his first musical experiences with gospel music, a music that he returned to at various stages of his career.\n\nAs a teenager Byther moved to Arizona, working on a cattle ranch and playing with a country & western band at weekends. <a href="https://www.last.fm/music/Byther+Smith">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Status Quo',
#   'oyentes': '915370',
#   'reproducciones': '12792073',
#   'bio_resumen': 'Status Quo is a British rock band (London, England)  founded by bassist Alan Lancaster and guitarist Francis Rossi in 1962.\n\nThey began as a rock and roll freakbeat band called The Spectres. By 1967, with very little commercial success, they discovered psychedelia and changed their name to Traffic (later Traffic Jam, to avoid confusion with Steve Winwood\'s Traffic.) At this time the line-up also included organist Roy Lynes and drummer John Coghlan. <a href="https://www.last.fm/music/Status+Quo">Read more on Last.fm</a>',
#   'pais': 'United Kingdom'},
#  {'artista': 'Junior Wells',
#   'oyentes': '184572',
#   'reproducciones': '1390338',
#   'bio_resumen': 'Junior Wells (December 9, 1934 - January 15, 1998), born Amos Blakemore, was a blues vocalist and harmonica player based in Chicago who was famous for playing with Muddy Waters, Buddy Guy, Magic Sam, Lonnie Brooks, The Rolling Stones and Van Morrison.\n\nHe was born in Memphis, Tennessee, and raised in Arkansas. Wells moved to Chicago in 1948 and first made his mark at age 18 playing in Muddy Waters\' band. He later worked with Buddy Guy in the 1960s and recorded for Delmark Records. <a href="https://www.last.fm/music/Junior+Wells">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': "Lightnin' Hopkins",
#   'oyentes': '360414',
#   'reproducciones': '3665641',
#   'bio_resumen': 'Samuel John "Lightnin\'" Hopkins (March 15, 1912 – January 30, 1982) was an American country blues singer, songwriter, guitarist and occasional pianist, from Centerville, Texas. Rolling Stone magazine ranked him number 71 on its list of the 100 greatest guitarists of all time.\n\nThe musicologist Robert "Mack" McCormick opined that Hopkins is "the embodiment of the jazz-and-poetry spirit, representing its ancient form in the single creator whose words and music are one act". <a href="https://www.last.fm/music/Lightnin%27+Hopkins">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Bonnie Raitt',
#   'oyentes': '788393',
#   'reproducciones': '8628326',
#   'bio_resumen': 'Bonnie Raitt, (born November 8, 1949) is an American blues and R&B singer, songwriter, and guitarist who was born in Burbank, California, the daughter of Broadway musical star John Raitt.\n\nRaitt began playing guitar at an early age, something not a lot of her high school girlfriends did. "I had played a little at school and at camp," she later recalled in a July 2002 interview. "My parents would drag me out to perform for my family, like all parents do, but it was a hobby—nothing more. <a href="https://www.last.fm/music/Bonnie+Raitt">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Blues Company',
#   'oyentes': '21963',
#   'reproducciones': '228244',
#   'bio_resumen': 'There are three similar bands with the same name.\n1. Blues Company - Hungary\'s No.1 Motorcycle-Blues Band\n2. Blues Company - Germany´s No.1 Blues Band\n3. Istambul Blues Company (İstanbul Blues Kumpanyası) - Blues band from turkey\n\n1.) A Blues company 1994-ben alakult magyar rockegyüttes, amely jellegzetes, blues alapú zenéjéről, és humoros, gyakran vulgáris hangvételű szövegeiről vált híressé. Gyakran lépnek fel motorostalálkozókon, fesztiválokon. <a href="https://www.last.fm/music/Blues+Company">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Eddy Wilsons Blues Band',
#   'oyentes': '1024',
#   'reproducciones': '3733',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Shemekia Copeland',
#   'oyentes': '69058',
#   'reproducciones': '507931',
#   'bio_resumen': 'Shemekia Copeland (b Harlem, New York City, 10 April 1979) is an American blues singer.\n\nThe daughter of blues guitarist and singer Johnny Copeland, she began to pursue a singing career in earnest at age 16, when her father\'s health began to decline; he took Shemekia on tour as his opening act, which helped establish her name on the blues circuit.\n\nShe landed a record deal with Alligator, which issued her debut album "Turn the Heat Up!" in 1998. The record was met with enthusiastic reviews <a href="https://www.last.fm/music/Shemekia+Copeland">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'The Nimmo Brothers',
#   'oyentes': '2955',
#   'reproducciones': '44590',
#   'bio_resumen': 'For over a decade The Nimmo Brothers, from Glasgow, Scotland have proven themselves to be one of the most respected exponents of modern blues the UK has seen since the blues boom of the 1960’s. It is from this period, that brothers Stevie and Alan Nimmo first drew their influences, which makes them the fine musicians they are today. Inspired by such greats as Peter Green’s Fleetwood Mac and John Mayall’s Bluesbreakers they had no doubt that when the time came <a href="https://www.last.fm/music/The+Nimmo+Brothers">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Memphis La Blusera',
#   'oyentes': '28308',
#   'reproducciones': '385419',
#   'bio_resumen': '"Memphis La Blusera" es una banda argentina de blues y rock nacida en el barrio porteño de La Paternal el 5 de mayo de 1978. Comenzaron a tocar como banda con temáticas muy sociales y trabajadoras, saliéndose de esa línea con el disco "Tonto Rompecabezas", donde se van al grano de lo que es las letras sobre el amor. Para su grabación en vivo de 25º aniversario en Luna Park, se revivió parte de la fama de la banda, que además visitó otros países como Chile. <a href="https://www.last.fm/music/Memphis+La+Blusera">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'The Bel-Aires',
#   'oyentes': '2712',
#   'reproducciones': '8552',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Wynonie Harris',
#   'oyentes': '116345',
#   'reproducciones': '616777',
#   'bio_resumen': 'Wynonie "Mr. Blues" Harris (August 24, 1915-June 14, 1969) was an American blues shouter and rhythm and blues singer.\n\nHe was born in Omaha, Nebraska. Harris traveled as a singer and dancer with the Lucky Millinder Big Band in his youth. His first big solo hit was in 1944 with his record "Who Threw The Whiskey in the Well". He was a dynamic live performer who brought a lot of attention to the emerging styles of rhythm and blues.\n\nHarris made a major contribution to the birth of rock and roll when he covered "Good Rocking Tonight" <a href="https://www.last.fm/music/Wynonie+Harris">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Guitar Shorty',
#   'oyentes': '43667',
#   'reproducciones': '318046',
#   'bio_resumen': 'There are two artists with the name \'Guitar Shorty\': \n1) Guitar Shorty was American blues guitarist, singer and songwriter David William Kearney  (born on 8 September 1934 ; died 20 April 2022) who was known for his explosive guitar style and wild stage antics. \n2) Guitar Shorty was American acoustic blues guitarist John Henry Fortescue (born on 24 January 1923; died 26 May 1976). \n\nI. Guitar Shorty (born David William Kearney on  8 September 1934 ; died 20 April 2022), was an American blues guitarist. <a href="https://www.last.fm/music/Guitar+Shorty">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Eddie Hope',
#   'oyentes': '1112',
#   'reproducciones': '4008',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Doyle Bramhall',
#   'oyentes': '18251',
#   'reproducciones': '123038',
#   'bio_resumen': 'Doyle Bramhall (1949.02.17/Dallas, TX - 2011.11.12/Alpine) was strictly a Texas blues musician, a talented guitarist, drummer and singer who has worked with Stevie Ray Vaughan and his brother Jimmie Vaughan. Bramhall is sometimes confused with his son, Doyle Bramhall II, who is also a singer, songwriter, and guitarist.\n\nIt was initially reported that Mr. Bramhall may have died as a result of complications from pneumonia. One of his final North Texas performances was at 2011\'s Main St. <a href="https://www.last.fm/music/Doyle+Bramhall">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Champion Jack Dupree',
#   'oyentes': '118422',
#   'reproducciones': '678786',
#   'bio_resumen': 'William Thomas Dupree (birth date disputed; died January 21, 1992, in Hanover, Germany), best known as Champion Jack Dupree, was an American blues pianist. He was the embodiment of the New Orleans blues and boogie woogie pianist. On his best known album, Blues from the Gutter, for Atlantic in 1959, he was accompanied on guitar by Larry Dale, whose playing on that record inspired Brian Jones of The Rolling Stones. Although best known as a singer and pianist in the New Orleans style <a href="https://www.last.fm/music/Champion+Jack+Dupree">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Eric Sardinas',
#   'oyentes': '57901',
#   'reproducciones': '468079',
#   'bio_resumen': 'Slide guitarist and singer-songwriter Eric Sardinas has a reputation for packing intensity into his live performances. Since the late-90s’ Sardinas has taken the stage thousands of times across the globe, with audiences growing exponentially each passing year. His six albums have displayed a distinct style that musically pushes the boundaries of rock and blues, and the world has taken notice. \n\nNow Sardinas has put his onstage lighting in a bottle for the new album Sticks & Stones <a href="https://www.last.fm/music/Eric+Sardinas">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Marcia Ball',
#   'oyentes': '41828',
#   'reproducciones': '305915',
#   'bio_resumen': 'Marcia Ball (born 20 March 1949) is an American blues singer and pianist born in Orange, Texas but who grew up in Vinton, Louisiana. This same region spawned other American blues greats, including Clifton Chenier, Janis Joplin, Lonnie Brooks, Stevie Ray Vaughan, The Fabulous Thunderbirds, and Kenny Neal.\n\nBorn into a musical family, Ball began playing piano at age 5, and showed an early interest in New Orleans style piano playing, as exemplified by Fats Domino, Professor Longhair, and James Booker. <a href="https://www.last.fm/music/Marcia+Ball">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Ray Charles',
#   'oyentes': '2727950',
#   'reproducciones': '43013714',
#   'bio_resumen': 'Ray Charles (Ray Charles Robinson,  Albany, Georgia, September 23, 1930 - Beverly Hills, California, June 10, 2004), was an American singer-songwriter, musician, arranger, and band leader. \n\nAs a rock and roll, rhythm & blues, soul, blues, jazz, country and pop musician he helped to shape the sound of rhythm & blues.\n\nHe brought a soulful sound to everything from country music ("I Can\'t Stop Loving You") to rock and roll ("Mess Around"), to pop standards to a now-iconic rendition of "America the Beautiful. <a href="https://www.last.fm/music/Ray+Charles">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Freddie King',
#   'oyentes': '409888',
#   'reproducciones': '3838063',
#   'bio_resumen': '\nFreddie King (September 3, 1934 – December 28, 1976), thought to have been born as Frederick Christian in Gilmer, Texas, originally recording as Freddy King, and nicknamed "the Texas Cannonball", was an influential African-American blues guitarist and singer. He is often mentioned as one of "the Three Kings" of electric blues guitar, along with Albert King and B.B. King (though he was the youngest of the three).\n\nKing\'s mother, Ella May King, and her brother, who both played the guitar, began teaching him to play at the age of six. <a href="https://www.last.fm/music/Freddie+King">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Eric Clapton',
#   'oyentes': '3345918',
#   'reproducciones': '79870206',
#   'bio_resumen': 'Eric Patrick Clapton CBE (born 30 March 1945) is an English rock and blues guitarist, singer, and songwriter. He is regarded as one of the most successful and influential guitarists in rock music. He ranked second in Rolling Stone\'s list of the "100 Greatest Guitarists of All Time" and fourth in Gibson\'s "Top 50 Guitarists of All Time". In 2023, Rolling Stone named Clapton the 35th best guitarist of all time. He was also named number five in Time magazine\'s list of "The 10 Best Electric Guitar Players" in 2009. <a href="https://www.last.fm/music/Eric+Clapton">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Solomon Burke',
#   'oyentes': '625178',
#   'reproducciones': '5301408',
#   'bio_resumen': 'Solomon Burke (born March 21, 1940 in Philadelphia, Pennsylvania, USA, died October 10, 2010 at Schiphol Airport, The Netherlands) was a soul music pioneer and member of the Rock and Roll Hall of Fame. Despite releasing numerous rnb chart hits in the 1960s, he never had a Top 20 hit on the pop charts. Burke\'s influence, however, has outstripped his mainstream commercial success. He is considered a legend of American music.\n\nHe began his adult life as a young preacher in Philadelphia, where he hosted a gospel radio show. <a href="https://www.last.fm/music/Solomon+Burke">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Joe Bonamassa',
#   'oyentes': '475577',
#   'reproducciones': '13852116',
# ...
#   'pais': 'Unknown'},
#  {'artista': 'Zucchero',
#   'oyentes': '373658',
#   'reproducciones': '5446934',
#   'bio_resumen': 'Zucchero (Italian for "sugar") is an Italian rock singer. He was born Adelmo Fornaciari on September 25, 1955 in the Italian province Reggio Emilia, Italy and has since become one of the most famous Italian singers.\n\nHe is probably best known internationally for the song Senza Una Donna, which is a duet with Paul Young and hit number 4 in the latter\'s native United Kingdom, where Zucchero has generally made little commercial impact, in 1991. He commenced his musical career in 1970 with his first single in 1976, and his first album in 1983. <a href="https://www.last.fm/music/Zucchero">Read more on Last.fm</a>',
#   'pais': 'Italy'},
#  {'artista': 'Gomez',
#   'oyentes': '630900',
#   'reproducciones': '11854928',
#   'bio_resumen': 'Gomez is a five-piece British act consisting of Ben Ottewell (vocals, guitar), Tom Gray (vocals, guitar, keyboards), Paul Blackburn (bass, guitar), Olly Peacock (drums), and Ian Ball (vocals, guitar, harmonica). Emerging during a time in which the majority of up-and-coming British bands were either retro-pop (à la Oasis), trip-hop (Portishead), or space rock (the Verve, Radiohead), Gomez were one of the few to feature bluesy influences. The Southport boys\' debut for Virgin Records <a href="https://www.last.fm/music/Gomez">Read more on Last.fm</a>',
#   'pais': 'United Kingdom'},
#  {'artista': 'Muddy Waters Blues Band',
#   'oyentes': '2442',
#   'reproducciones': '17262',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Aerosmith',
#   'oyentes': '4588950',
#   'reproducciones': '127189422',
#   'bio_resumen': 'Aerosmith is an American rock band formed in Boston, Massachusetts, in 1970. The group consists of lead vocalist Steven Tyler, bassist Tom Hamilton, drummer Joey Kramer, and guitarists Joe Perry and Brad Whitford. Their musical style is primarily rooted in blues-based hard rock and also incorporates elements of pop rock, heavy metal, glam metal, and rhythm and blues. The band’s primary songwriting partnership between Tyler and Perry is often referred to as the Toxic Twins. <a href="https://www.last.fm/music/Aerosmith">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Big Bill Broonzy',
#   'oyentes': '190733',
#   'reproducciones': '1480177',
#   'bio_resumen': 'Big Bill Broonzy (June 26, 1893 – August 15, 1958) was a prolific American blues singer, songwriter and guitarist. His career began in the 1920s when he played country blues to mostly African-American audiences. Through the 1930s and 1940s he successfully navigated a transition in style to a more urban blues sound popular with working class African-American audiences. In the 1950s a return to his traditional folk-blues roots made him one of the leading figures of the emerging American folk music revival and an international star. <a href="https://www.last.fm/music/Big+Bill+Broonzy">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Santana',
#   'oyentes': '2752151',
#   'reproducciones': '50687515',
#   'bio_resumen': 'Santana is a Latin music and rock band formed in San Francisco, California in 1966 by Mexican-American guitarist Carlos Santana. The band came to public attention with their performance of "Soul Sacrifice" at Woodstock in 1969. This exposure helped propel their first album, also named Santana, into a hit, followed in the next two years by Abraxas and Santana III. Lineup changes were common. Carlos Santana\'s increasing involvement with guru Sri Chinmoy took the band into more esoteric music, though it never lost its Latin influence. <a href="https://www.last.fm/music/Santana">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Earl King',
#   'oyentes': '40948',
#   'reproducciones': '193079',
#   'bio_resumen': 'Earl King (Earl Silas Johnson IV, New Orleans, Louisiana, February 7, 1934 – April 17, 2003)  (not to be confused with Earl Connelly King (born Earl B. Connelly, Jr. in Philadelphia)) was an American Rhythm & Blues singer, guitarist, and songwriter.\n\nA composer of well known standards such as "Come On" (covered by Jimi Hendrix) and Professor Longhair\'s "Big Chief", he is an important figure in New Orleans R&B music.\n\nHis father, a local piano player, died when King was still a baby, and he was brought up by his mother. <a href="https://www.last.fm/music/Earl+King">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Buddaheads',
#   'oyentes': '8496',
#   'reproducciones': '80752',
#   'bio_resumen': 'Buddaheads (also known as  The Buddaheads, Buddah Heads, B.B. & The Screaming Buddah Heads and  BB Chung King & The Buddaheads). BAND MEMBERS:Alan Mirikitani, guitar and lead vocals, Boyd Lefan, bass,Joe "The Bricklayer" Pafumi, drums.\n\nGuitarist/Singer Alan Mirikitani realized that he wanted to pursue a career in music after playing an eighth-grade dance with his first band while in junior high school in his hometown of Downey.\n\n"After we got done, some girls came and sat in our laps," he said. <a href="https://www.last.fm/music/Buddaheads">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Charlie Parker',
#   'oyentes': '934452',
#   'reproducciones': '15021377',
#   'bio_resumen': 'Charles Christopher "Bird" Parker, Jr (29th August 1920 – 12th March 1955) was a U.S. bebop saxophonist and composer. Early in his career Parker was dubbed Yardbird; this was later shortened to "Bird" (or sometimes "Yard") and remained Parker\'s nickname for the rest of his life, and inspiration for the titles of his works such as "Ornithology and Yardbird suite".\n\nParker is commonly considered the greatest bebop jazz musician. In terms of influence and impact <a href="https://www.last.fm/music/Charlie+Parker">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Esther Phillips',
#   'oyentes': '249613',
#   'reproducciones': '1457443',
#   'bio_resumen': 'Esther Phillips (December 23, 1935 – August 7, 1984) was an American singer. Phillips was known for her R&B vocals, but she was a versatile singer, also performing pop, country, jazz, blues and soul music.\n\nBorn Esther Mae Jones in Galveston, Texas, when she was an adolescent, her parents divorced, and she was forced to divide her time between her father in Houston and her mother in the Watts area of Los Angeles. Because she was brought up singing in church <a href="https://www.last.fm/music/Esther+Phillips">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Alabama 3',
#   'oyentes': '317161',
#   'reproducciones': '4540869',
#   'bio_resumen': 'Alabama 3 are a band originating from Brixton, England, their music incorporates elements of country, acid house,  blues and gospel. \n\nNamed for the Alabama 2, a legal case in the American deep South during the 1930s, in which two black men were hanged for allegedly raping a white woman. The name is also a nod to other victims of injustice like the Birmingham 6 and Guildford 4. In the United States, they are known as A3, after they were sued by the legendary country outfit Alabama. <a href="https://www.last.fm/music/Alabama+3">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Saffire-The Uppity Blues Women',
#   'oyentes': '4603',
#   'reproducciones': '23110',
#   'bio_resumen': 'It\'s not often that dreams come true. In the case of the acoustic blues trio, Saffire--The Uppity Blues Women, that\'s just what happened. Over the course of nine recordings and thousands of gigs, the group has gone from virtual obscurity to one of the most popular, witty, and just plain satisfying acoustic blues groups on the scene today. These women tear into their material with passion, dedication, and originality. Every song they cover becomes theirs, and their originals blend seamlessly with their interpretations. <a href="https://www.last.fm/music/+noredirect/Saffire-The+Uppity+Blues+Women">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'David Gogo',
#   'oyentes': '9942',
#   'reproducciones': '85180',
#   'bio_resumen': 'Born in Nanaimo, British Columbia, David received a ukulele at age 4 and his first guitar at age 5. Encouraged by his parents throughout his childhood, the guitar began to captivate him. By the age of 16 Gogo was working steadily as a professional musician. His interest in the blues could be considered unusual for a teenager in the early 1980\'s. Nonetheless, David was drawn to the emotional power and raw depth of such performers as Howling Wolf and Son House. <a href="https://www.last.fm/music/David+Gogo">Read more on Last.fm</a>',
#   'pais': 'United Kingdom'},
#  {'artista': "Ray Collins' Hot Club",
#   'oyentes': '12345',
#   'reproducciones': '107171',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'John Hammond',
#   'oyentes': '93004',
#   'reproducciones': '587213',
#   'bio_resumen': 'There are more than 2 artists that go by the name of John Hammond, two are mentioned below:\n\n1. John Paul Hammond (born 13th November 1942), also known as "John Hammond Jr", is a blues singer and guitarist. He usually plays acoustic guitars and dobros and sings in a barrelhouse style. Since 1962, when he made his debut on Vanguard Records, Hammond has made 29 albums. In the 1990s he recorded for the Pointblank label. Hammond has earned one Grammy Award and been nominated for four others. <a href="https://www.last.fm/music/John+Hammond">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Lucky Peterson',
#   'oyentes': '51688',
#   'reproducciones': '427053',
#   'bio_resumen': 'Lucky Peterson (born Judge Kenneth Peterson in Buffalo, NY, on 13 December 1964; died 17 May 2020) was an American musician who played contemporary blues, fusing soul, R&B, gospel and rock and roll.\n\nPeterson played his first gig at age three. By the time he was five, he had already recorded his first single, produced by none other than the legendary Willie Dixon. Before Peterson turned six, his career had been propelled into the national spotlight with television appearances on The Ed Sullivan Show <a href="https://www.last.fm/music/Lucky+Peterson">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': "Howlin' Wolf",
#   'oyentes': '829551',
#   'reproducciones': '11095454',
#   'bio_resumen': 'Chester Arthur Burnett  (June 10, 1910 in White Station, Mississippi, United States – January 10, 1976 in Hines, Illinois, United States), known as Howlin\' Wolf, was an influential American blues singer, guitarist and harmonica player.\n\nWith a booming voice and looming physical presence, Burnett is commonly ranked among the leading performers in electric blues; musician and critic Cub Koda declared, "no one could match Howlin\' Wolf for the singular <a href="https://www.last.fm/music/Howlin%27+Wolf">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Amy Winehouse',
#   'oyentes': '4464029',
#   'reproducciones': '195177465',
#   'bio_resumen': 'Amy Jade Winehouse was an English singer and songwriter. She was known for her deep, expressive contralto vocals and her eclectic mix of musical genres, including soul, rhythm and blues, reggae and jazz.\n\nA member of the National Youth Jazz Orchestra during her youth, Winehouse signed to Simon Fuller\'s 19 Management in 2002 and soon recorded a number of songs before signing a publishing deal with EMI. She also formed a working relationship with producer Salaam Remi through these record publishers. <a href="https://www.last.fm/music/Amy+Winehouse">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Mojo Blues Band',
#   'oyentes': '7016',
#   'reproducciones': '89086',
#   'bio_resumen': 'The founders of the band played before 1977 in clubs of Vienna. In 1977 Palden won a boogie woogie contest. The first prize was a record contract. They decided to form a band, which they named "Mojo Blues Band". \n\nThe line up was:\nguitar, vocals Erik Trauner\npiano Joachim Palden\nbass Matthias Mitsch\ndrums Bobby Sperling\n\nBeing the only blues band in Vienna they were often booked as backing band for blues artists who were touring in Austria. They played for example with Johnny Shines, J. <a href="https://www.last.fm/music/Mojo+Blues+Band">Read more on Last.fm</a>',
#   'pais': 'Unknown'},
#  {'artista': 'Big Mama Thornton',
#   'oyentes': '250820',
#   'reproducciones': '1505916',
#   'bio_resumen': 'Big Mama Thornton (Willie Mae Thornton, December 11, 1926, Ariton, AL - July 25, 1984, Los Angeles, CA) was an American blues musician. \n\nHer introduction to music, as with most fellow blues legends, started in the Baptist church. The daughter of a minister, she and her six siblings began to sing at a very early age. While still a child, Willie Mae taught herself to play the drums and harmonica, and by the age of 14, she had run away from home to make her career in secular music. <a href="https://www.last.fm/music/Big+Mama+Thornton">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Sam Cooke',
#   'oyentes': '1791994',
#   'reproducciones': '30721445',
#   'bio_resumen': 'Samuel Cooke (born January 22, 1931 in Clarksdale, Mississippi; died December 11, 1964 in Los Angeles, California) was a popular and influential American gospel, R&B, soul, and pop, songwriter and singer,  recognized as one of the true founders of soul music. Often referred to as The King of Soul, Cooke had 29 Top 40 hits in the U.S. between 1957 and 1964 including major hits You Send Me, A Change Is Gonna Come, Chain Gang and Wonderful World. Cooke <a href="https://www.last.fm/music/Sam+Cooke">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Marc Broussard',
#   'oyentes': '284616',
#   'reproducciones': '2654398',
#   'bio_resumen': 'Marc Broussard (born January 14, 1982) is an American singer and songwriter. The Louisiana native released his first major album (with Island Def Jam Records) on August 3, 2004. The album\'s title Carencro pays tribute to the musician\'s hometown of Carencro, Louisiana. His style is best described as "Bayou Soul," a mix of funk, blues, R&B, rock, and pop, matched with distinct Southern roots.\n\nMarc is best known for the songs "Where You Are" and "Home. <a href="https://www.last.fm/music/Marc+Broussard">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Ben B. Beckendorf',
#   'oyentes': '2006',
#   'reproducciones': '5275',
#   'bio_resumen': 'biografia no encontrada',
#   'pais': 'Unknown'},
#  {'artista': 'Chris Smither',
#   'oyentes': '87444',
#   'reproducciones': '844828',
#   'bio_resumen': 'Chris Smither (born November 11, 1944 in Miami, Florida) is an American folk/blues singer, guitarist, and songwriter. He grew up mainly in New Orleans and attended the University of the Americas in Mexico City, planning on becoming an anthropologist, but transferred to Tulane University after a year, during which time he discovered the music of Mississippi John Hurt. While in Paris for a junior year abroad, he spent his time playing guitar rather than attending classes and was kicked out of college as a result. <a href="https://www.last.fm/music/Chris+Smither">Read more on Last.fm</a>',
#   'pais': 'United States'},
#  {'artista': 'Chick Willis',
#   'oyentes': '4231',
#   'reproducciones': '17483',
#   'bio_resumen': 'Robert "Chick" Willis (September 24, 1934 – December 7, 2013)   R.I.P.\n\n\nBluesman Chick Willis, who was currently residing in Forsyth, Georgia, passed away on Saturday, December 7, 2013 after a lengthy battle with cancer. Willis was 79 years old.\n\nHe was born in 1934 in Cabiness, Georgia.  His dad was a railroad man and the Willis family moved to Atlanta when he was about 6 years of age.  He was surrounded by music as a youngster and displayed an early affinity by teaching himself guitar while already having experience with vocals <a href="https://www.last.fm/music/Chick+Willis">Read more on Last.fm</a>',
#   'pais': 'Unknown'}]

# %%
#dataframe de la lista final extraida de lastfm (con paises)
df_blues_2 = pd.DataFrame(lista_artistas)

df_blues_2
# Out:
#                artista  oyentes reproducciones  \
# 0           W.C. Clark     9252          41127
# 1          Chet Atkins   293379        3200761
# 2            Sue Foley    36605         313880
# 3           Ellis Hall     5471          24534
# 4       The Limp Twins   136255         998008
# ..                 ...      ...            ...
# 245          Sam Cooke  1791994       30721445
# 246     Marc Broussard   284616        2654398
# 247  Ben B. Beckendorf     2006           5275
# 248      Chris Smither    87444         844828
# 249       Chick Willis     4231          17483
#
#                                            bio_resumen           pais
# 0    W.C. Clark (born Wesley Curley Clark in Austin...  United States
# 1    Chester Burton Atkins born 20 June 1924 - Died...  United States
# 2    Sue Foley (born March 29, 1968, Ottawa, Ontari...         Canada
# 3    Ellis Hall Jr. (born May 10, 1951 in Savannah,...  United States
# 4    The Limp Twins are Will Holland (a.k.a quantic...        Unknown
# ..                                                 ...            ...
# 245  Samuel Cooke (born January 22, 1931 in Clarksd...  United States
# 246  Marc Broussard (born January 14, 1982) is an A...  United States
# 247                            biografia no encontrada        Unknown
# 248  Chris Smither (born November 11, 1944 in Miami...  United States
# 249  Robert "Chick" Willis (September 24, 1934 – De...        Unknown
#
# [250 rows x 5 columns]

# %%
df_blues_2.to_csv('artistas_blues.csv', index=False, encoding="utf-8")
