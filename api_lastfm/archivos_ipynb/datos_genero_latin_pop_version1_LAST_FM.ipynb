# %%
import requests

from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

import json

import time

# %%
cliente = '######'

# %%
# Información que Devuelve artist.getinfo: 
# 1. **Biografía:** en el campo bio. 
# 2. **Popularidad y Estadísticas:** campos listeners (oyentes únicos) y playcount (número total de reproducciones). 
# 3. **Artistas Similares:** Se encuentran en una lista bajo el campo similar.

# %%
cliente

genero = 'latin pop' #--> separandolo solo hay que modificar esta variable, es un codigo más limpio que podemos usar todas

limite = 50

parametros = {'method':'tag.getTopArtists', 'tag':genero, 'api_key': cliente,'format':'json', 'limit':limite, 'page':1}

# %%
URL = 'http://ws.audioscrobbler.com/2.0/'

respuesta = requests.get(URL, params=parametros)

# %%
datos_last_fm = respuesta.json()

# %%
len(datos_last_fm['topartists'])
# Out:
# 2

# %%
claves_top = datos_last_fm['topartists']

# %%
claves_top.keys() #attr contiene los metadatos (atributos) de la solicitud, incluyendo la  page.
# Out:
# dict_keys(['artist', '@attr'])

# %%
nombre_artista = ['Shakira', 'Morat']
url_api = "http://ws.audioscrobbler.com/2.0/"
lista_artistas = []

# %%
def llamar_lastfm_api(method, artist_name, cliente):
        params = {'method': method,'artist': artist_name,'api_key': cliente,'format': 'json'}
        response = requests.get(url_api, params=params)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error {response.status_code}: No se pudo obtener la información para el método {method}")
            return
print(f"Obteniendo detalles de: {nombre_artista}")
# Out:
# Obteniendo detalles de: ['Shakira', 'Morat']

# %%
artistas_a_consultar = ["Shakira", "Morat"]
lista_artistas = []
for nombre_artista in artistas_a_consultar:
    print(f"--- Consultando: {nombre_artista} ---")
    datos_artista = llamar_lastfm_api('artist.getinfo', nombre_artista, cliente)
    if datos_artista and 'artist' in datos_artista:
        artista_data = datos_artista['artist']
        oyentes = artista_data.get('stats', {}).get('listeners', 'arista no encontrado')
        reproducciones = artista_data.get('stats', {}).get('playcount', 'N/D')
        bio_content = artista_data.get('bio', {}).get('content', '')
        if not bio_content or bio_content.strip() == "":
            bio_resumen = 'biografia no encontrada'
        else:
            bio_resumen = artista_data.get('bio', {}).get('summary')
        lista_artistas_dict = {'artista': artista_data.get('name', nombre_artista),'oyentes': oyentes, 'reproducciones': reproducciones, 'bio_resumen': bio_resumen}
        lista_artistas.append(lista_artistas_dict)
        print(f"Datos de {nombre_artista} procesados y guardados.")
    else:
        print(f"No se pudo obtener información de {nombre_artista}")
# Out:
# --- Consultando: Shakira ---
# Datos de Shakira procesados y guardados.
# --- Consultando: Morat ---
# Datos de Morat procesados y guardados.

# %%
lista_artistas
# Out:
# [{'artista': 'Shakira',
#   'oyentes': '4640737',
#   'reproducciones': '168412816',
#   'bio_resumen': 'Shakira Isabel Mebarak Ripoll is a Colombian singer. Born and raised in Barranquilla, She made her recording debut with Sony Music Colombia at the age of 13. Following the commercial failure of her first two albums, Magia (1991) and Peligro (1993), she rose to prominence in Hispanic countries with her next albums, Pies Descalzos (1995) and Dónde Están los Ladrones? (1998). She entered the English-language market with her fifth album, Laundry Service (2001), which sold over 13 million copies worldwide. <a href="https://www.last.fm/music/Shakira">Read more on Last.fm</a>'},
#  {'artista': 'Morat',
#   'oyentes': '287335',
#   'reproducciones': '20750056',
#   'bio_resumen': 'Morat is a Colombian band formed in the country\'s capital city, Bogotá. The band is formed by Juan Pablo Isaza (guitars and vocals), Juan Pablo Villamil (banjo and vocals) and the brothers Simón Vargas (bass and choruses) and Martín Vargas (percussion and choirs). Previously, until the end of 2016, drummer Alejandro Posada had been in the band, but the percussionist had to leave the project, being subsequently replaced by Martín Vargas.\n\nThey began to stand out internationally in 2015 <a href="https://www.last.fm/music/Morat">Read more on Last.fm</a>'}]

# %%
## quiero traer mi archivo json y leerlo aquí (load)

# %%
ruta_json = 'artistas_latin_pop.json'

# %%
with open(ruta_json, 'r', encoding='utf-8') as archivo:
        artistas_a_consultar = json.load(archivo)
        print(f"Lista de artistas: {artistas_a_consultar}")
# Out:
# Lista de artistas: ['La Oreja de Van Gogh', 'Ricky Martin', 'Rodrigo', 'Thalia', 'Rodrigo', 'Los Tucanes De Tijuana', 'Paulina Rubio', 'Chayanne', 'Celia Cruz', 'Rodrigo', 'Rodrigo', 'Juanes', 'Chayanne', 'Thalia', 'Chayanne', 'Laura Pausini', 'Ana Torroja', 'La Oreja de Van Gogh', 'Alejandro Sanz', 'Rodrigo', 'Chayanne', 'Armando Manzanero', 'Donato Y Estefano', 'Paulina Rubio', 'Alejandro Sanz', 'Alejandro Sanz', 'La Oreja de Van Gogh', 'Paulina Rubio', 'Thalia', 'Christina Aguilera', 'Ana Torroja', 'Eros Ramazzotti', 'La Oreja de Van Gogh', 'Eros Ramazzotti', 'La Oreja de Van Gogh', 'Celia Cruz', 'La Oreja de Van Gogh', 'La Oreja de Van Gogh', 'La Oreja de Van Gogh', 'La Oreja de Van Gogh', 'Alejandro Sanz', 'La Oreja de Van Gogh', 'La Oreja de Van Gogh', 'Gloria Estefan', 'Paulina Rubio', 'Christina Aguilera', 'Chayanne', 'Paulina Rubio', 'Alejandro Sanz', 'Alejandro Sanz', 'El Cuarteto De Nos', 'Paulina Rubio', 'Ricardo Arjona', 'El Cuarteto De Nos', 'Celia Cruz', 'Los Tucanes De Tijuana', 'Alejandro Sanz', 'Los Tucanes De Tijuana', 'Nek', 'Beto Quintanilla', 'Walter Olmos', 'Rodrigo', 'Banda XXI', 'Rodrigo', 'Rodrigo', 'Luis Alberto Posada', 'Fey', 'Walter Olmos', 'Rodrigo', 'Thalia', 'Luis Miguel', 'El Cuarteto De Nos', 'Alejandro Sanz', 'Ana Torroja', 'Celia Cruz', 'Ana Torroja', 'El Cuarteto De Nos', 'Ana Torroja', 'Ana Torroja', 'Paulina Rubio', 'Jean Carlos', 'Debelah Morgan', 'Jennifer Lopez', 'Ana Torroja', 'Ana Torroja', 'Rey Ruiz', 'Monica Naranjo', 'Luis Miguel', 'Bertin Osborne', 'Chayanne', 'Alejandro Sanz', 'Alejandro Sanz', 'Alejandro Sanz', 'La Retrocumbia', 'La Retrocumbia', 'La Gran Banda', 'La Retrocumbia', 'Luis Alberto Posada', 'La Retrocumbia', 'La Retrocumbia', 'Walter Olmos', 'Walter Olmos', 'Beto Quintanilla', 'Walter Olmos', 'Tru La La', 'Walter Olmos', 'Julio Iglesias', 'Donato Y Estefano', 'La Oreja de Van Gogh', 'Ana Torroja', 'Luisito Muñoz', 'Jean Carlos', 'Chayanne', 'Ana Torroja', 'Donato Y Estefano', 'Jimmy Bosch', 'Ana Torroja', 'Rodrigo', 'Ricky Martin', 'Juanes', 'Banda XXI', 'Shakira', 'Walter Olmos', 'Donato Y Estefano', 'Alejandro Sanz', 'Donato Y Estefano', 'Luis Alberto Posada', 'Luis Alberto Posada', 'Donato Y Estefano', 'Polo Montañez', 'Ana Torroja', 'Ana Torroja', 'Celia Cruz', 'Issac Delgado', 'Ana Torroja', 'Ana Torroja', 'Thalia', 'Walter Olmos', 'Alejandro Sanz', 'Ana Torroja', 'Nek', 'Julieta Venegas', 'Ana Torroja', 'La Mosca', 'Juanes', 'Ana Torroja', 'El Cuarteto De Nos', 'Rodrigo', 'Luis Alberto Posada', "Los Chaque's", 'Sabroso', 'José José', 'Jean Carlos', 'Shakira', 'Aleks Syntek', 'Diego Torres', 'Shakira', 'Shakira', 'Carlos Vives', 'Laura Pausini', 'Shakira', 'Jennifer Lopez', 'Andrés Cepeda', 'Marc Anthony', 'Shakira', 'Rios De Gloria', 'Bacilos', 'Carlos Vives', 'Guaraná', 'Monica Naranjo', 'Shakira', 'Miguel Bosé', 'Diego Torres', 'Bacilos', 'Marc Anthony', 'Carlos Vives', 'Luis Miguel', 'Miguel Bosé', 'Miguel Bosé', 'Miguel Bosé', 'Alejandro Sanz', 'Raulin Rodriguez', 'Alejandro Sanz', 'Shakira', 'Bacilos', 'Carlos Vives', 'Carlos Vives', 'Miguel Bosé', 'Sin Bandera', 'Enrique Iglesias', 'Sin Bandera', 'Enrique Iglesias', 'Shakira', 'Diego Torres', 'Shakira', 'Shakira', 'Sin Bandera', 'Sin Bandera', 'Cristian Castro', 'Cristian Castro', 'Los Tigres Del Norte', 'Cristian Castro', 'Aleks Syntek', 'Sabroso', 'Los Razos', 'Beto Quintanilla', 'Lemon', 'Jean Carlos', "Mo' Horizons", 'Benny', 'Rodrigo', 'Shakira', 'Bacilos', 'Miguel Bosé', 'Carlos Vives', 'Diego Torres', 'Marc Anthony', 'Marc Anthony', 'Beny Moré', 'Shakira', 'Shakira', 'Enrique Iglesias', 'Shakira', 'Marc Anthony', 'Jennifer Lopez', 'Shakira', 'Laura Pausini', 'Shakira', 'Alejandro Parreño', 'Shakira', 'Jimmy Gutierrez', 'Enrique Iglesias', 'Shakira', 'Shakira', 'Jennifer Lopez', 'Joaquín Sabina', 'Enrique Iglesias', 'Carlos Vives', 'Shakira', 'Rios De Gloria', 'Carlos Vives', 'Miguel Bosé', 'Diego Torres', 'Orquesta Tabaco Y Ron', 'Diego Torres', 'Jennifer Lopez', 'Malú', 'Bacilos', 'Skeewiff', ' ...

# %%
## en la lista json tenemos duplicados, por lo que no nos sirve

# %%
lista_artistas
# Out:
# [{'artista': 'Shakira',
#   'oyentes': '4640737',
#   'reproducciones': '168412816',
#   'bio_resumen': 'Shakira Isabel Mebarak Ripoll is a Colombian singer. Born and raised in Barranquilla, She made her recording debut with Sony Music Colombia at the age of 13. Following the commercial failure of her first two albums, Magia (1991) and Peligro (1993), she rose to prominence in Hispanic countries with her next albums, Pies Descalzos (1995) and Dónde Están los Ladrones? (1998). She entered the English-language market with her fifth album, Laundry Service (2001), which sold over 13 million copies worldwide. <a href="https://www.last.fm/music/Shakira">Read more on Last.fm</a>'},
#  {'artista': 'Morat',
#   'oyentes': '287335',
#   'reproducciones': '20750056',
#   'bio_resumen': 'Morat is a Colombian band formed in the country\'s capital city, Bogotá. The band is formed by Juan Pablo Isaza (guitars and vocals), Juan Pablo Villamil (banjo and vocals) and the brothers Simón Vargas (bass and choruses) and Martín Vargas (percussion and choirs). Previously, until the end of 2016, drummer Alejandro Posada had been in the band, but the percussionist had to leave the project, being subsequently replaced by Martín Vargas.\n\nThey began to stand out internationally in 2015 <a href="https://www.last.fm/music/Morat">Read more on Last.fm</a>'}]

# %%
df_latin_pop_LastFm = pd.DataFrame(lista_artistas) 

df_latin_pop_LastFm.head()
# Out:
#    artista  oyentes reproducciones  \
# 0  Shakira  4640737      168412816
# 1    Morat   287335       20750056
#
#                                          bio_resumen
# 0  Shakira Isabel Mebarak Ripoll is a Colombian s...
# 1  Morat is a Colombian band formed in the countr...

# %%
df_latin_pop_LastFm.to_csv("df_latin_pop_LastFm.csv", index=False, encoding="utf-8")

# %%
df = pd.read_csv('df_latin_pop.csv') ##leemos el df

# %%
df
# Out:
#                   Artista     Género   Tipo                            Nombre  \
# 0    La Oreja de Van Gogh  latin pop  track                               Pop
# 1            Ricky Martin  latin pop  track       She Bangs - Spanish Version
# 2                 Rodrigo  latin pop  track                      Como Le Digo
# 3                  Thalia  latin pop  track       Entre El Mar Y Una Estrella
# 4                 Rodrigo  latin pop  track                    Fuego y Pasion
# ..                    ...        ...    ...                               ...
# 745           Miguel Bosé  latin pop  track  Habana (con Alejandro Fernández)
# 746                   RBD  latin pop  track           Cuando El Amor Se Acaba
# 747        Ricardo Arjona  latin pop  track                           Desnuda
# 748        Franco De Vita  latin pop  track                           Ay Dios
# 749        Alejandro Sanz  latin pop  track        Y sólo se me ocurre amarte
#
#       Año                      ID
# 0    2000  4FXSEdmbbeGmPIQltH27C8
# 1    2000  4ti5pZ0zs1PDf1eQswskFB
# 2    2000  4nH1lpWkgzQPpTYPPjWKaI
# 3    2000  2KNtKG2X0jpOIgVunVbAkQ
# 4    2000  0SBHkYiZh8ih1RHoOcDtHl
# ..    ...                     ...
# 745  2004  2qnSc14v8T5YSqNeeZls4k
# 746  2004  50y4eCnuuWIhJl5uuCqVa5
# 747  2004  5WVsQTW7BE1ClEDCmDKzci
# 748  2004  0Sd0bKypMwcUTUgHH9TCov
# 749  2004  3zvnloMEkCiIFRsZDUJPaW
#
# [750 rows x 6 columns]

# %%
df.columns = df.columns.str.strip()

# %%
artistas = df['Artista'] ##accedemos a artistas

# %%
artistas
# Out:
# 0      La Oreja de Van Gogh
# 1              Ricky Martin
# 2                   Rodrigo
# 3                    Thalia
# 4                   Rodrigo
#                ...
# 745             Miguel Bosé
# 746                     RBD
# 747          Ricardo Arjona
# 748          Franco De Vita
# 749          Alejandro Sanz
# Name: Artista, Length: 750, dtype: object

# %%
artistas_unicos = set(artistas) ## eliminamos duplicados

# %%
artistas_unicos
# Out:
# {'Alejandra Guzman',
#  'Alejandro Fernández',
#  'Alejandro Parreño',
#  'Alejandro Sanz',
#  'Aleks Syntek',
#  'Alexandre Pires',
#  'Ana Torroja',
#  'Andrés Cepeda',
#  'Andy Aguilera',
#  'Armando Manzanero',
#  'Bacanos',
#  'Bacilos',
#  'Banda XXI',
#  'Belinda',
#  'Benny',
#  'Beny Moré',
#  'Bertin Osborne',
#  'Beto Quintanilla',
#  'Cabas',
#  'Carlos Jean',
#  'Carlos Ponce',
#  'Carlos Vives',
#  'Celia Cruz',
#  'Chayanne',
#  'Chic Savanna',
#  'Christina Aguilera',
#  'Clave Cubana',
#  'Cristian Castro',
#  'Cubismo',
#  'Damas Gratis',
#  'Danni Ubeda',
#  'David Bisbal',
#  'David Calzado y su Charanga Habanera',
#  'Debelah Morgan',
#  'Diego Torres',
#  'Donato Y Estefano',
#  'Draco Rosa',
#  'Edwin Bonilla',
#  'El Cuarteto De Nos',
#  'Enrique Iglesias',
#  'Eros Ramazzotti',
#  'Eydie Gormé',
#  'Fey',
#  'Francisco Céspedes',
#  'Franco De Vita',
#  'Geno',
#  'Gloria Estefan',
#  'Gloria Trevi',
#  'Glup!',
#  'Grupo Aliados',
#  'Grupo Escuela del Amor',
#  'Grupo Exterminador',
#  'Guaraná',
#  'Ha*Ash',
#  'Huey Dunbar',
#  'Issac Delgado',
#  'Jarabe De Palo',
#  'Jean Carlos',
#  'Jennifer Lopez',
#  'Jimmy Bosch',
#  'Jimmy Gutierrez',
#  'Jimmy Sabater',
#  'Joaquín Sabina',
#  'Jon Secada',
#  'José José',
#  'Juan Formell y Los Van Van',
#  'Juanes',
#  'Julieta Venegas',
#  'Julio Iglesias',
#  'KEMA',
#  'LU',
#  'La Barra',
#  'La Fiesta',
#  'La Gran Banda',
#  'La Mona Jimenez',
#  'La Mosca',
#  'La Oreja de Van Gogh',
#  'La Quinta Estacion',
#  'La Retrocumbia',
#  'La-33',
#  'Latin Dreams',
#  'Laura Miller',
#  'Laura Pausini',
#  'Lemon',
#  'Los Cachorros de Juan Villarreal',
#  "Los Chaque's",
#  'Los Fachero´s',
#  'Los Incomparables De Tijuana',
#  'Los Legendarios',
#  'Los Originales De San Juan',
#  'Los Palmeras',
#  'Los Playeros',
#  'Los Razos',
#  'Los Tigres Del Norte',
#  'Los Tucanes De Tijuana',
#  'Lucas Arnau',
#  'Luis Alberto Posada',
#  'Luis Fonsi',
#  'Luis Miguel',
#  'Luisito Muñoz',
#  'Malú',
#  'Marc Anthony',
#  'Mauricio & PalodeAgua',
#  'Melody',
#  'Michael Bublé',
#  'Miguel Bosé',
#  'Miranda!',
#  "Mo' Horizons",
#  'Moises Angulo',
#  'Monica Naranjo',
#  'Murga Contrafarsa',
#  'Natalia Lafourcade',
#  'Nek',
#  'Nika',
#  'Noelia',
#  'OBK',
#  'Obie Bermudez',
#  'Orquesta Tabaco Y Ron',
#  'Paco Pineda y Su Grupo Tex Mex',
#  'Papá Levante',
#  'Patricia Manterola',
#  'Paulina Rubio',
#  'Pepe Aguilar',
#  'Polo Montañez',
#  'Qarto Aparte',
#  'RBD',
#  'Raul Paz',
#  'Raulin Rodriguez',
#  'Rey Ruiz',
#  'Ricardo Arjona',
#  'Ricardo Montaner',
#  'Ricky Martin',
#  'Rios De Gloria',
#  'Rodrigo',
#  'Sabroso',
#  'Salsa Celtica',
#  'Sandy e Junior',
#  'Sebastian',
#  'Shakira',
#  'Shalim',
#  'Sin Bandera',
#  'Skeewiff',
#  'Thalia',
#  'Tiziano Ferro',
#  'Tommy Torres',
#  'Tranzas',
#  'Tru La La',
#  'Víctor Manuelle',
#  'Wakal',
#  'Walter Olmos',
#  'Willie Bobo',
#  'Yahir'}

# %%
 ## introducimos artistas unicos

# %%
artistas_unicos
lista_artistas = []
for nombre_artista in artistas_unicos:
    print(f"--- Consultando: {nombre_artista} ---")
    datos_artista = llamar_lastfm_api('artist.getinfo', nombre_artista, cliente)
    if datos_artista and 'artist' in datos_artista:
        artista_data = datos_artista['artist']
        oyentes = artista_data.get('stats', {}).get('listeners', 'arista no encontrado')
        reproducciones = artista_data.get('stats', {}).get('playcount', 'N/D')
        bio_content = artista_data.get('bio', {}).get('content', '')
        if not bio_content or bio_content.strip() == "":
            bio_resumen = 'biografia no encontrada'
        else:
            bio_resumen = artista_data.get('bio', {}).get('summary')
        lista_artistas_dict = {'artista': artista_data.get('name', nombre_artista),'oyentes': oyentes, 'reproducciones': reproducciones, 'bio_resumen': bio_resumen}
        lista_artistas.append(lista_artistas_dict)
        print(f"Datos de {nombre_artista} procesados y guardados.")
    else:
        print(f"No se pudo obtener información de {nombre_artista}")
# Out:
# --- Consultando: Jon Secada ---
# Datos de Jon Secada procesados y guardados.
# --- Consultando: Noelia ---
# Datos de Noelia procesados y guardados.
# --- Consultando: Los Legendarios ---
# Datos de Los Legendarios procesados y guardados.
# --- Consultando: Geno ---
# Datos de Geno procesados y guardados.
# --- Consultando: La Oreja de Van Gogh ---
# Datos de La Oreja de Van Gogh procesados y guardados.
# --- Consultando: Celia Cruz ---
# Datos de Celia Cruz procesados y guardados.
# --- Consultando: Draco Rosa ---
# Datos de Draco Rosa procesados y guardados.
# --- Consultando: Jimmy Sabater ---
# Datos de Jimmy Sabater procesados y guardados.
# --- Consultando: Raul Paz ---
# Datos de Raul Paz procesados y guardados.
# --- Consultando: Luis Miguel ---
# Datos de Luis Miguel procesados y guardados.
# --- Consultando: Andy Aguilera ---
# Datos de Andy Aguilera procesados y guardados.
# --- Consultando: Jarabe De Palo ---
# Datos de Jarabe De Palo procesados y guardados.
# --- Consultando: El Cuarteto De Nos ---
# Datos de El Cuarteto De Nos procesados y guardados.
# --- Consultando: Eydie Gormé ---
# Datos de Eydie Gormé procesados y guardados.
# --- Consultando: Grupo Escuela del Amor ---
# No se pudo obtener información de Grupo Escuela del Amor
# --- Consultando: Ricardo Montaner ---
# Datos de Ricardo Montaner procesados y guardados.
# --- Consultando: Bacanos ---
# Datos de Bacanos procesados y guardados.
# --- Consultando: Chayanne ---
# Datos de Chayanne procesados y guardados.
# --- Consultando: David Bisbal ---
# Datos de David Bisbal procesados y guardados.
# --- Consultando: Nika ---
# Datos de Nika procesados y guardados.
# --- Consultando: RBD ---
# Datos de RBD procesados y guardados.
# --- Consultando: Malú ---
# Datos de Malú procesados y guardados.
# --- Consultando: Rodrigo ---
# Datos de Rodrigo procesados y guardados.
# --- Consultando: Sebastian ---
# Datos de Sebastian procesados y guardados.
# --- Consultando: Andrés Cepeda ---
# Datos de Andrés Cepeda procesados y guardados.
# --- Consultando: Ricardo Arjona ---
# Datos de Ricardo Arjona procesados y guardados.
# --- Consultando: Marc Anthony ---
# Datos de Marc Anthony procesados y guardados.
# --- Consultando: Melody ---
# Datos de Melody procesados y guardados.
# --- Consultando: Aleks Syntek ---
# Datos de Aleks Syntek procesados y guardados.
# --- Consultando: Chic Savanna ---
# Datos de Chic Savanna procesados y guardados.
# --- Consultando: Raulin Rodriguez ---
# Datos de Raulin Rodriguez procesados y guardados.
# --- Consultando: La Quinta Estacion ---
# Datos de La Quinta Estacion procesados y guardados.
# --- Consultando: La Retrocumbia ---
# Datos de La Retrocumbia procesados y guardados.
# --- Consultando: Mauricio & PalodeAgua ---
# Datos de Mauricio & PalodeAgua procesados y guardados.
# --- Consultando: Monica Naranjo ---
# Datos de Monica Naranjo procesados y guardados.
# --- Consultando: La Fiesta ---
# Datos de La Fiesta procesados y guardados.
# --- Consultando: Wakal ---
# Datos de Wakal procesados y guardados.
# --- Consultando: Enrique Iglesias ---
# Datos de Enrique Iglesias procesados y guardados.
# --- Consultando: Carlos Jean ---
# Datos de Carlos Jean procesados y guardados.
# --- Consultando: Julieta Venegas ---
# Datos de Julieta Venegas procesados y guardados.
# --- Consultando: LU ---
# Datos de LU procesados y guardados.
# --- Consultando: Tranzas ---
# Datos de Tranzas procesados y guardados.
# --- Consultando: Banda XXI ---
# Datos de Banda XXI procesados y guardados.
# --- Consultando: OBK ---
# Datos de OBK procesados y guardados.
# --- Consultando: Ricky Martin ---
# Datos de Ricky Martin procesados y guardados.
# --- Consultando: Issac Delgado ---
# Datos de Issac Delgado procesados y guardados.
# --- Consultando: Los Tigres Del Norte ---
# Datos de Los Tigres Del Norte procesados y guardados.
# --- Consultando: Shakira ---
# Datos de Shakira procesados y guardados.
# --- Consultando: Qarto Aparte ---
# Datos de Qarto Aparte procesados y guardados.
# --- Consultando: Alejandro Sanz ---
# Datos de Alejandro Sanz procesados y guardados.
# --- Consultando: Skeewiff ---
# Datos de Skeewiff procesados y guardados.
# --- Consultando: Danni Ubeda ---
# Datos de Danni Ubeda procesados y guardados.
# --- Consultando: Shalim ---
# Datos de Shalim procesados y guardados.
# --- Consultando: La-33 ---
# Datos de La-33 procesados y guardados.
# --- Consultando: Eros Ramazzotti ---
# Datos de Eros Ramazzotti procesados y guardados.
# --- Consultando: Bertin Osborne ---
# Datos de Bertin Osborne procesados y guardados.
# --- Consultando: Huey Dunbar ---
# Datos de Huey Dunbar procesados y guardados.
# --- Consultando: La Mosca ---
# Datos de La Mosca procesados y guardados.
# --- Consultando: Los Playeros ---
# Datos de Los Playeros procesados y guardados.
# --- Consultando: Luis Alberto Posada ---
# Datos de Luis Alberto Posada procesados y guardados.
# --- Consultando: Alejandro Fernández ---
# Datos de Alejandro Fernández procesados y guardados.
# --- Consultando: Francisco Céspedes ---
# Datos de Francisco Céspedes procesados y guardados.
# --- Consultando: Guaraná ---
# Datos de Guaraná procesados y guardados.
# --- Consultando: Walter Olmos ---
# Datos de Walter Olmos procesados y guardados.
# --- Consultando: Luisito Muñoz ---
# Datos de Luisito Muñoz procesados y guardados.
# --- Consultando: Grupo Aliados ---
# Datos de Grupo Aliados procesados y guardados.
# --- Consultando: Los Tucanes De Tijuana ---
# Datos de Los Tucanes De Tijuana procesados y guardados.
# --- Consultando: Alexandre Pires ---
# Datos de Alexandre Pires procesados y guardados.
# --- Consultando: Glup! ---
# Datos de Glup! procesados y guardados.
# --- Consultando: Belinda ---
# Datos de Belinda procesados y guardados.
# --- Consultando: La Barra ---
# Datos de La Barra procesados y guardados.
# --- Consultando: Julio Iglesias ---
# Datos de Julio Iglesias procesados y guardados.
# --- Consultando: Diego Torres ---
# Datos de Diego Torres procesados y guardados.
# --- Consultando: Sin Bandera ---
# Datos de Sin Bandera procesados y guardados.
# --- Consultando: Armando Manzanero ---
# Datos de Armando Manzanero procesados y guardados.
# --- Consultando: Tommy Torres ---
# Datos de Tommy Torres procesados y guardados.
# --- Consultando: Lemon ---
# Datos de Lemon procesados y guardados.
# --- Consultando: Obie Bermudez ---
# Datos de Obie Bermudez procesados y guardados.
# --- Consultando: Los Originales De San Juan ---
# Datos de Los Originales De San Juan procesados y guardados.
# --- Consultando: Pepe Aguilar ---
# Datos de Pepe Aguilar procesados y guardados.
# --- Consultando: Jimmy Gutierrez ---
# Datos de Jimmy Gutierrez procesados y guardados.
# --- Consultando: Laura Miller ---
# Datos de Laura Miller procesados y guardados.
# --- Consultando: Salsa Celtica ---
# Datos de Salsa Celtica procesados y guardados.
# --- Consultando: Beny Moré ---
# Datos de Beny Moré procesados y guardados.
# --- Consultando: Jennifer Lopez ---
# Datos de Jennifer Lopez procesados y guardados.
# --- Consultando: Los Razos ---
# Datos de Los Razos procesados y guardados.
# --- Consultando: Michael Bublé ---
# Datos de Michael Bublé procesados y guardados.
# --- Consultando: Rios De Gloria ---
# Datos de Rios De Gloria procesados y guardados.
# --- Consultando: Grupo Exterminador ---
# Datos de Grupo Exterminador procesados y guardados.
# --- Consultando: Gloria Trevi ---
# Datos de Gloria Trevi procesados y guardados.
# --- Consultando: Los Chaque's ---
# Datos de Los Chaque's procesados y guardados.
# --- Consultando: Mo' Horizons ---
# Datos de Mo' Horizons procesados y guardados.
# --- Consultando: Jean Carlos ---
# Datos de Jean Carlos procesados y guardados.
# --- Consultando: Cristian Castro ---
# Datos de Cristian Castro procesados y guardados.
# --- Consultando: Juan Formell y Los Van Van ---
# Datos de Juan Formell y Los Van Van procesados y guardados.
# --- Consultando: Tiziano Ferro ---
# Datos de Tiziano Ferro procesados y guardados.
# --- Consultando: Beto Quintanilla ---
# Datos de Beto Quintanilla procesados y guardados.
# --- Consultando: Miranda! ---
# Datos de Miranda! procesados y guardados.
# --- Consultando: Polo Montañez ---
# Datos de Polo Montañez procesados y guardados.
# --- Consultando: Luis Fonsi ---
# Datos de Luis Fonsi procesados y guardados.
# --- Consultando: KEMA ---
# Datos de KEMA procesados y guardados.
# --- Consultando: Christina Aguilera ---
# Datos de Christina Aguilera procesados y guardados.
# --- Consultando: Patricia Manterola ---
# Datos de Patricia Manterola procesados y guardados.
# --- Consultando: Moises Angulo ---
# Datos de Moises Angulo procesados y guardados.
# --- Consultando: Papá Levante ---
# Datos de Papá Levante procesados y guardados.
# --- Consultando: Cubismo ---
# Datos de Cubismo procesados y guardados.
# --- Consultando: Fey ---
# Datos de Fey procesados y guardados.
# --- Consultando: Tru La La ---
# Datos de Tru La La procesados y guardados.
# --- Consultando: Murga Contrafarsa ---
# Datos de Murga Contrafarsa procesados y guardados.
# --- Consultando: La Gran Banda ---
# Datos de La Gran Banda procesados y guardados.
# --- Consultando: Alejandro Parreño ---
# Datos de Alejandro Parreño procesados y guardados.
# --- Consultando: Debelah Morgan ---
# Datos de Debelah Morgan procesados y guardados.
# --- Consultando: Latin Dreams ---
# Datos de Latin Dreams procesados y guardados.
# --- Consultando: Paco Pineda y Su Grupo Tex Mex ---
# Datos de Paco Pineda y Su Grupo Tex Mex procesados y guardados.
# --- Consultando: Joaquín Sabina ---
# Datos de Joaquín Sabina procesados y guardados.
# --- Consultando: Ha*Ash ---
# Datos de Ha*Ash procesados y guardados.
# --- Consultando: Willie Bobo ---
# Datos de Willie Bobo procesados y guardados.
# --- Consultando: Juanes ---
# Datos de Juanes procesados y guardados.
# --- Consultando: Los Fachero´s ---
# Datos de Los Fachero´s procesados y guardados.
# --- Consultando: Gloria Estefan ---
# Datos de Gloria Estefan procesados y guardados.
# --- Consultando: Alejandra Guzman ---
# Datos de Alejandra Guzman procesados y guardados.
# --- Consultando: Clave Cubana ---
# Datos de Clave Cubana procesados y guardados.
# --- Consultando: Natalia Lafourcade ---
# Datos de Natalia Lafourcade procesados y guardados.
# --- Consultando: Víctor Manuelle ---
# Datos de Víctor Manuelle procesados y guardados.
# --- Consultando: José José ---
# Datos de José José procesados y guardados.
# --- Consultando: Lucas Arnau ---
# Datos de Lucas Arnau procesados y guardados.
# --- Consultando: Carlos Ponce ---
# Datos de Carlos Ponce procesados y guardados.
# --- Consultando: Carlos Vives ---
# Datos de Carlos Vives procesados y guardados.
# --- Consultando: Los Incomparables De Tijuana ---
# Datos de Los Incomparables De Tijuana procesados y guardados.
# --- Consultando: La Mona Jimenez ---
# Datos de La Mona Jimenez procesados y guardados.
# --- Consultando: Ana Torroja ---
# Datos de Ana Torroja procesados y guardados.
# --- Consultando: Paulina Rubio ---
# Datos de Paulina Rubio procesados y guardados.
# --- Consultando: Franco De Vita ---
# Datos de Franco De Vita procesados y guardados.
# --- Consultando: Orquesta Tabaco Y Ron ---
# Datos de Orquesta Tabaco Y Ron procesados y guardados.
# --- Consultando: Sandy e Junior ---
# Datos de Sandy e Junior procesados y guardados.
# --- Consultando: Thalia ---
# Datos de Thalia procesados y guardados.
# --- Consultando: Edwin Bonilla ---
# Datos de Edwin Bonilla procesados y guardados.
# --- Consultando: Cabas ---
# Datos de Cabas procesados y guardados.
# --- Consultando: Yahir ---
# Datos de Yahir procesados y guardados.
# --- Consultando: Donato Y Estefano ---
# Datos de Donato Y Estefano procesados y guardados.
# --- Consultando: Nek ---
# Datos de Nek procesados y guardados.
# --- Consultando: Miguel Bosé ---
# Datos de Miguel Bosé procesados y guardados.
# --- Consultando: Los Palmeras ---
# Datos de Los Palmeras procesados y guardados.
# --- Consultando: Jimmy Bosch ---
# Datos de Jimmy Bosch procesados y guardados.
# --- Consultando: Rey Ruiz ---
# Datos de Rey Ruiz procesados y guardados.
# --- Consultando: Bacilos ---
# Datos de Bacilos procesados y guardados.
# --- Consultando: Sabroso ---
# Datos de Sabroso procesados y guardados.
# --- Consultando: Laura Pausini ---
# Datos de Laura Pausini procesados y guardados.
# --- Consultando: Benny ---
# Datos de Benny procesados y guardados.
# --- Consultando: David Calzado y su Charanga Habanera ---
# Datos de David Calzado y su Charanga Habanera procesados y guardados.
# --- Consultando: Los Cachorros de Juan Villarreal ---
# Datos de Los Cachorros de Juan Villarreal procesados y guardados.
# --- Consultando: Damas Gratis ---
# Datos de Damas Gratis procesados y guardados.

# %%
len(lista_artistas)
# Out:
# 151

# %%
df_artistas_latin_pop_LastFm = pd.DataFrame(lista_artistas)

# %%
df_artistas_latin_pop_LastFm
# Out:
#                                   artista oyentes reproducciones  \
# 0                              Jon Secada  253200        1780136
# 1                                  Noelia   82084         458386
# 2                         Los Legendarios  104518         843549
# 3                                    Geno    1998           8425
# 4                    La Oreja de Van Gogh  629390       18638355
# ..                                    ...     ...            ...
# 146                         Laura Pausini  555670       21836726
# 147                                 Benny  141803        1135285
# 148  David Calzado Y Su Charanga Habanera   20640         258617
# 149      Los Cachorros De Juan Villarreal   11123          95580
# 150                          Damas Gratis   84912        1395783
#
#                                            bio_resumen
# 0    Juan Francisco Secada (born October 4, 1962 in...
# 1    There are several artists who perform under th...
# 2                              biografia no encontrada
# 3    Geno is a g-funk artist from Chicago, IL. He r...
# 4    La Oreja de Van Gogh (English: Van Gogh's Ear)...
# ..                                                 ...
# 146  Laura Pausini is a five-time Grammy Award winn...
# 147  There are multiple artist called Benny:\n\n1. ...
# 148  \n    La Charanga Habanera y David Calzado Bio...
# 149                            biografia no encontrada
# 150  Damas Gratis es un grupo musical de cumbia vil...
#
# [151 rows x 4 columns]

# %%
## convertimos nuevamente en df y en csv

# %%
df_artistas_latin_pop_LastFm.to_csv("artista_latin_pop.csv", index=False, encoding="utf-8")

# %%
## debemos enlazar en la consulta el país, y debe proceder de biografía

# %%
## generamos un diccionario BASE, formado por GENTILICIOS.

# %%
PAIS_A_GENTILICIO = {
    "Afghanistan": "Afghan",
    "Albania": "Albanian",
    "Algeria": "Algerian",
    "Argentina": "Argentinian",
    "Australia": "Australian",
    "Austria": "Austrian",
    "Belgium": "Belgian",
    "Bolivia": "Bolivian",
    "Brazil": "Brazilian",
    "Canada": "Canadian",
    "Chile": "Chilean",
    "China": "Chinese",
    "Colombia": "Colombian",
    "Costa Rica": "Costa Rican",
    "Cuba": "Cuban",
    "Denmark": "Dane",
    "Egypt": "Egyptian",
    "France": "French",
    "Germany": "German",
    "Greece": "Greek",
    "India": "Indian",
    "Indonesia": "Indonesian",
    "Ireland": "Irish",
    "Italy": "Italian",
    "Jamaica": "Jamaican",
    "Japan": "Japanese",
    "Mexico": "Mexican",
    "Netherlands": "Dutch",
    "New Zealand": "New Zealander",
    "Nigeria": "Nigerian",
    "Norway": "Norwegian",
    "Peru": "Peruvian",
    "Poland": "Pole",
    "Portugal": "Portuguese",
    "Russia": "Russian",
    "South Korea": "South Korean",
    "Spain": "Spaniard",
    "Sweden": "Swede",
    "Turkey": "Turk",
    "Ukraine": "Ukrainian",
    "United Kingdom": "Briton",
    "United States": "American",
    "United States_adj": "American",
    "United Kingdom_adj": "British",
    "France_adj": "French",
    "Germany_adj": "German",
    "Spain_adj": "Spanish"}

# %%
# DICCIONARIO INVERTIDO PARA BÚSQUEDA EFICIENTE
# Clave: Gentilicio (lo que busco en la bio), Valor: País
GENTILICIO_A_PAIS = {gentilicio.lower(): pais.replace('_adj', '')
    for pais, gentilicio in PAIS_A_GENTILICIO.items()}

# %%
def extraer_pais_de_biografia(bio_resumen, gentilicio_a_pais_map):
    bio_normalizada = bio_resumen.lower()
    for gentilicio, pais in gentilicio_a_pais_map.items():
        # Usamos ' ' + gentilicio + ' ' para buscar la palabra completa y evitar coincidencias parciales
        if f' {gentilicio} ' in bio_normalizada or bio_normalizada.startswith(f'{gentilicio} '):
            return pais
        
        if bio_normalizada.endswith(gentilicio):
             return pais
    return 'Unknown'

for artista_data in lista_artistas:
    bio = artista_data['bio_resumen']
    pais_encontrado = extraer_pais_de_biografia(bio, GENTILICIO_A_PAIS)
    artista_data['pais'] = pais_encontrado #aqui agregamos la clave pais en nuestro diccionario
print(lista_artistas)
# Out:
# [{'artista': 'Jon Secada', 'oyentes': '253200', 'reproducciones': '1780136', 'bio_resumen': 'Juan Francisco Secada (born October 4, 1962 in Havana, Cuba)  better known as Jon Secada is an Afro-Cuban singer and songwriter. Secada was born in Havana, Cuba, and raised in Hialeah, Florida. He has won two Grammy Awards and sold 20 million albums since his English-language debut album in 1992, made famous for his song Just Another Day. His music fuses funk, soul, pop and Latin percussion. Secada also has appeared as a songwriter for Gloria Estefan, Jennifer Lopez, Ricky Martin, Mandy Moore and other performers. <a href="https://www.last.fm/music/Jon+Secada">Read more on Last.fm</a>', 'pais': 'Unknown'}, {'artista': 'Noelia', 'oyentes': '82084', 'reproducciones': '458386', 'bio_resumen': 'There are several artists who perform under the name Noelia.\n\n 1.) Noelia Lorenzo, this International Latin Music Super Star was raised  in Miami, Florida, mostly known as Noelia, is a Puerto Rican pop singer who rose to fame in 1999. During her career she has had 10 Latin Billboard Top 40 hits, and has eighteen worldwide gold and nine worldwide multi-platinum -certified albums, along with one RIAA-certified Goldrecord in the United States. She has sold more than 4.5 million Albums worldwide.  <a href="https://www.last.fm/music/Noelia">Read more on Last.fm</a>', 'pais': 'Unknown'}, {'artista': 'Los Legendarios', 'oyentes': '104518', 'reproducciones': '843549', 'bio_resumen': 'biografia no encontrada', 'pais': 'Unknown'}, {'artista': 'Geno', 'oyentes': '1998', 'reproducciones': '8425', 'bio_resumen': 'Geno is a g-funk artist from Chicago, IL. He released album Unknown Lifestyle vol. 1 in 1999. <a href="https://www.last.fm/music/Geno">Read more on Last.fm</a>', 'pais': 'Unknown'}, {'artista': 'La Oreja de Van Gogh', 'oyentes': '629390', 'reproducciones': '18638355', 'bio_resumen': 'La Oreja de Van Gogh (English: Van Gogh\'s Ear) is a Spanish band. The name of the band references the Dutch painter Vincent Van Gogh who allegedly cut off his own ear. It was formed in Spain in 1996, when guitarist Pablo Benegas, bassist Álvaro Fuentes, keyboardist Xabi San Martín and drummer Haritz Garde met at university.\n\nSan Martin was the vocalist until Amaia Montero joined the band by request from Benegas, just after he met her at a dinner party. <a href="https://www.last.fm/music/La+Oreja+de+Van+Gogh">Read more on Last.fm</a>', 'pais': 'Netherlands'}, {'artista': 'Celia Cruz', 'oyentes': '547142', 'reproducciones': '4653151', 'bio_resumen': 'Celia Cruz (born as Úrsula Hilaria Celia de la Caridad Cruz Alfonso in La Habana, Cuba on 21 October 1925 – died 16 July 2003) was a Cuban-American and was one of the most successful salsa performers of the 20th century, having earned twenty-three gold albums. She was renowned internationally as the "Queen of Salsa" as well as "La Guarachera de Cuba.\n\nIn 1950, Cruz made her first major breakthrough, after the lead singer of the La Sonora Matancera, a renowned Cuban orchestra, left the group and Cruz was called to fill in. <a href="https://www.last.fm/music/Celia+Cruz">Read more on Last.fm</a>', 'pais': 'Cuba'}, {'artista': 'Draco Rosa', 'oyentes': '30274', 'reproducciones': '467579', 'bio_resumen': 'Born Robert Edward Rosa Suarez on June 27, 1969, Long Island, New York. As "Robby Rosa" he was a member of Menudo from Valentine\'s Day, 1984 to 1987. He replaced Johnny Lozada in Menudo and soon became another fan favorite. He sang such hits like Tu Sabes A Chocolate, Hold Me and Like A Cannonball, which was featured in Hollywood hit Cannonball Run 2. He was replaced in Menudo by Ruben Gomez after the band\'s manager denied Rosa the opportunity to contribute songs to the group. <a href="https://www.last.fm/music/+noredirect/Draco+Rosa">Read more on Last.fm</a>', 'pais': 'Unknown'}, {'artista': 'Jimmy Sabater', 'oyentes': '18066', 'reproducciones': '93965', 'bio_resumen': 'Jimmy Sabater (April 11, 1946 - February 8, 2012) was b ...

# %%
df_artistas_latin_pop_LastFm = pd.DataFrame(lista_artistas)

# %%
df_artistas_latin_pop_LastFm
# Out:
#                                   artista oyentes reproducciones  \
# 0                              Jon Secada  253200        1780136
# 1                                  Noelia   82084         458386
# 2                         Los Legendarios  104518         843549
# 3                                    Geno    1998           8425
# 4                    La Oreja de Van Gogh  629390       18638355
# ..                                    ...     ...            ...
# 146                         Laura Pausini  555670       21836726
# 147                                 Benny  141803        1135285
# 148  David Calzado Y Su Charanga Habanera   20640         258617
# 149      Los Cachorros De Juan Villarreal   11123          95580
# 150                          Damas Gratis   84912        1395783
#
#                                            bio_resumen         pais
# 0    Juan Francisco Secada (born October 4, 1962 in...      Unknown
# 1    There are several artists who perform under th...      Unknown
# 2                              biografia no encontrada      Unknown
# 3    Geno is a g-funk artist from Chicago, IL. He r...      Unknown
# 4    La Oreja de Van Gogh (English: Van Gogh's Ear)...  Netherlands
# ..                                                 ...          ...
# 146  Laura Pausini is a five-time Grammy Award winn...        Italy
# 147  There are multiple artist called Benny:\n\n1. ...      Belgium
# 148  \n    La Charanga Habanera y David Calzado Bio...      Unknown
# 149                            biografia no encontrada      Unknown
# 150  Damas Gratis es un grupo musical de cumbia vil...      Unknown
#
# [151 rows x 5 columns]

# %%
df_artistas_latin_pop_LastFm.to_csv("artista_latin_pop.csv", index=False, encoding="utf-8")

# %%
### finalmente obtenermos otro df_cvs con los datos necesarios para realizar nuestras consultas en my SQL
